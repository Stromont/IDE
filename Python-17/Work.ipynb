# %%
import requests # Импортируем библиотеку requests
url = 'https://www.cbr-xml-daily.ru/daily_json.js' # Определяем значение URL страницы для запроса
response = requests.get(url) # Делаем GET-запрос к ресурсу и результат ответа сохраняем в переменной response

# %%
print(response)
# Out:
# <Response [200]>

# %%
print(response.text)
# Out:
# {
#     "Date": "2025-06-24T11:30:00+03:00",
#     "PreviousDate": "2025-06-21T11:30:00+03:00",
#     "PreviousURL": "\/\/www.cbr-xml-daily.ru\/archive\/2025\/06\/21\/daily_json.js",
#     "Timestamp": "2025-06-23T18:00:00+03:00",
#     "Valute": {
#         "AUD": {
#             "ID": "R01010",
#             "NumCode": "036",
#             "CharCode": "AUD",
#             "Nominal": 1,
#             "Name": "Австралийский доллар",
#             "Value": 50.201,
#             "Previous": 50.9632
#         },
#         "AZN": {
#             "ID": "R01020A",
#             "NumCode": "944",
#             "CharCode": "AZN",
#             "Nominal": 1,
#             "Name": "Азербайджанский манат",
#             "Value": 46.0543,
#             "Previous": 46.1774
#         },
#         "GBP": {
#             "ID": "R01035",
#             "NumCode": "826",
#             "CharCode": "GBP",
#             "Nominal": 1,
#             "Name": "Фунт стерлингов",
#             "Value": 105.4206,
#             "Previous": 105.4041
#         },
#         "AMD": {
#             "ID": "R01060",
#             "NumCode": "051",
#             "CharCode": "AMD",
#             "Nominal": 100,
#             "Name": "Армянских драмов",
#             "Value": 20.2788,
#             "Previous": 20.3541
#         },
#         "BYN": {
#             "ID": "R01090B",
#             "NumCode": "933",
#             "CharCode": "BYN",
#             "Nominal": 1,
#             "Name": "Белорусский рубль",
#             "Value": 26.3797,
#             "Previous": 26.3596
#         },
#         "BGN": {
#             "ID": "R01100",
#             "NumCode": "975",
#             "CharCode": "BGN",
#             "Nominal": 1,
#             "Name": "Болгарский лев",
#             "Value": 46.0947,
#             "Previous": 46.0696
#         },
#         "BRL": {
#             "ID": "R01115",
#             "NumCode": "986",
#             "CharCode": "BRL",
#             "Nominal": 1,
#             "Name": "Бразильский реал",
#             "Value": 14.2469,
#             "Previous": 14.3053
#         },
#         "HUF": {
#             "ID": "R01135",
#             "NumCode": "348",
#             "CharCode": "HUF",
#             "Nominal": 100,
#             "Name": "Форинтов",
#             "Value": 22.27,
#             "Previous": 22.4585
#         },
#         "VND": {
#             "ID": "R01150",
#             "NumCode": "704",
#             "CharCode": "VND",
#             "Nominal": 10000,
#             "Name": "Донгов",
#             "Value": 31.2819,
#             "Previous": 31.3618
#         },
#         "HKD": {
#             "ID": "R01200",
#             "NumCode": "344",
#             "CharCode": "HKD",
#             "Nominal": 10,
#             "Name": "Гонконгских долларов",
#             "Value": 99.9136,
#             "Previous": 10.0181
#         },
#         "GEL": {
#             "ID": "R01210",
#             "NumCode": "981",
#             "CharCode": "GEL",
#             "Nominal": 1,
#             "Name": "Лари",
#             "Value": 28.7122,
#             "Previous": 28.7868
#         },
#         "DKK": {
#             "ID": "R01215",
#             "NumCode": "208",
#             "CharCode": "DKK",
#             "Nominal": 1,
#             "Name": "Датская крона",
#             "Value": 12.0855,
#             "Previous": 12.0794
#         },
#         "AED": {
#             "ID": "R01230",
#             "NumCode": "784",
#             "CharCode": "AED",
#             "Nominal": 1,
#             "Name": "Дирхам ОАЭ",
#             "Value": 21.3185,
#             "Previous": 21.3755
#         },
#         "USD": {
#             "ID": "R01235",
#             "NumCode": "840",
#             "CharCode": "USD",
#             "Nominal": 1,
#             "Name": "Доллар США",
#             "Value": 78.2923,
#             "Previous": 78.5016
#         },
#         "EUR": {
#             "ID": "R01239",
#             "NumCode": "978",
#             "CharCode": "EUR",
#             "Nominal": 1,
#             "Name": "Евро",
#             "Value": 89.8388,
#             "Previous": 90.1356
#         },
#         "EGP": {
#             "ID": "R01240",
#             "NumCode": "818",
#             "CharCode": "EGP",
#             "Nominal": 10,
#             "Name": "Египетских фунтов",
#             "Value": 15.4456,
#             "Previous": 15.4942
#         },
#         "INR": {
#             "ID": "R01270",
#             "NumCode": "356",
#             "CharCode": "INR",
#             "Nominal": 100,
#             "Name": "Индийских рупий",
#             "Value": 90.1902,
#             "Previous": 90.6346
#         },
#         "IDR": {
#             "ID": "R01280",
#             "NumCode": "360",
#             "CharCode": "IDR",
#             "Nominal": 10000,
#             "Name": "Рупий",
#             "Value": 47.7421,
#             "Previous": 47.9311
#         },
#         "KZT": {
#             "ID": "R01335",
#             "NumCode": "398",
#             "CharCode": "KZT",
#             "Nominal": 100,
#             "Name": "Тенге",
#             "Value": 15.0109,
#             "Previous": 15.1095
#         },
#         "CAD": {
#             "ID": "R01350",
#             "NumCode": "124",
#             "CharCode": "CAD",
#             "Nominal": 1,
#             "Name": "Канадский доллар",
#             "Value": 57.0311,
#             "Previous": 57.2002
#         },
#         "QAR": {
#             "ID": "R01355",
#             "NumCode": "634",
#             "CharCode": "QAR",
#             "Nominal": 1,
#             "Name": "Катарский риал",
#             "Value": 21.5089,
#             "Previous": 21.5664
#         },
#         "KGS": {
#             "ID": "R01370",
#             "NumCode": "417",
#             "CharCode": "KGS",
#             "Nominal": 100,
#             "Name": "Сомов",
#             "Value": 89.5654,
#             "Previous": 89.7674
#         },
#         "CNY": {
#             "ID": "R01375",
#             "NumCode": "156",
#             "CharCode": "CNY",
#             "Nominal": 1,
#             "Name": "Юань",
#             "Value": 10.8691,
#             "Previous": 10.9021
#         },
#         "MDL": {
#             "ID": "R01500",
#             "NumCode": "498",
#             "CharCode": "MDL",
#             "Nominal": 10,
#             "Name": "Молдавских леев",
#             "Value": 45.7128,
#             "Previous": 45.6702
#         },
#         "NZD": {
#             "ID": "R01530",
#             "NumCode": "554",
#             "CharCode": "NZD",
#             "Nominal": 1,
#             "Name": "Новозеландский доллар",
#             "Value": 46.5526,
#             "Previous": 47.0696
#         },
#         "NOK": {
#             "ID": "R01535",
#             "NumCode": "578",
#             "CharCode": "NOK",
#             "Nominal": 10,
#             "Name": "Норвежских крон",
#             "Value": 77.7319,
#             "Previous": 78.1375
#         },
#         "PLN": {
#             "ID": "R01565",
#             "NumCode": "985",
#             "CharCode": "PLN",
#             "Nominal": 1,
#             "Name": "Злотый",
#             "Value": 21.0395,
#             "Previous": 21.1783
#         },
#         "RON": {
#             "ID": "R01585F",
#             "NumCode": "946",
#             "CharCode": "RON",
#             "Nominal": 1,
#             "Name": "Румынский лей",
#             "Value": 17.8006,
#             "Previous": 17.924
#         },
#         "XDR": {
#             "ID": "R01589",
#             "NumCode": "960",
#             "CharCode": "XDR",
#             "Nominal": 1,
#             "Name": "СДР (специальные права заимствования)",
#             "Value": 106.7602,
#             "Previous": 106.9341
#         },
#         "SGD": {
#             "ID": "R01625",
#             "NumCode": "702",
#             "CharCode": "SGD",
#             "Nominal": 1,
#             "Name": "Сингапурский доллар",
#             "Value": 60.6588,
#             "Previous": 61.0907
#         },
#         "TJS": {
#             "ID": "R01670",
#             "NumCode": "972",
#             "CharCode": "TJS",
#             "Nominal": 10,
#             "Name": "Сомони",
#             "Value": 79.0831,
#             "Previous": 79.2017
#         },
#         "THB": {
#             "ID": "R01675",
#             "NumCode": "764",
#             "CharCode": "THB",
#             "Nominal": 10,
#             "Name": "Батов",
#             "Value": 23.73,
#             "Previous": 23.9247
#         },
#         "TRY": {
#             "ID": "R01700J",
#             "NumCode": "949",
#             "CharCode": "TRY",
#             "Nominal": 10,
#             "Name": "Турецких лир",
#             "Value": 19.7825,
#             "Previous": 19.866
#         },
#         "TMT": {
#             "ID": "R01710A",
#             "NumCode": "934",
#             "CharCode": "TMT",
#             "Nominal": 1,
#             "Name": "Новый туркменский манат",
#             "Value": 22.3692,
#             "Previous": 22.429
#         },
#         "UZS": {
#             "ID": "R01717",
#             "NumCode": "860",
#             "CharCode": "UZS",
#             "Nominal": 10000,
#             "Name": "Узбекских сумов",
#             "Value": 62.6492,
#             "Previous": 62.505
#         },
#         "UAH": {
#             "ID": "R01720",
#             "NumCode": "980",
#             "CharCode": "UAH",
#             "Nominal": 10,
#             "Name": "Гривен",
#             "Value": 18.6988,
#             "Previous": 18.7652
#         },
#         "CZK": {
#             "ID": "R01760",
#             "NumCode": "203",
#             "CharCode": "CZK",
#             "Nominal": 10,
#             "Name": "Чешских крон",
#             "Value": 36.121,
#             "Previous": 36.4192
#         },
#         "SEK": {
#             "ID": "R01770",
#             "NumCode": "752",
#             "CharCode": "SEK",
#             "Nominal": 10,
#             "Name": "Шведских крон",
#             "Value": 81.1999,
#             "Previous": 81.417
#         },
#         "CHF": {
#             "ID": "R01775",
#             "NumCode": "756",
#             "CharCode": "CHF",
#             "Nominal": 1,
#             "Name": "Швейцарский франк",
#             "Value": 95.7119,
#             "Previous": 96.2029
#         },
#         "RSD": {
#             "ID": "R01805F",
#             "NumCode": "941",
#             "CharCode": "RSD",
#             "Nominal": 100,
#             "Name": "Сербских динаров",
#             "Value": 76.7586,
#             "Previous": 77.2082
#         },
#         "ZAR": {
#             "ID": "R01810",
#             "NumCode": "710",
#             "CharCode": "ZAR",
#             "Nominal": 10,
#             "Name": "Рэндов",
#             "Value": 43.3719,
#             "Previous": 43.5443
#         },
#         "KRW": {
#             "ID": "R01815",
#             "NumCode": "410",
#             "CharCode": "KRW",
#             "Nominal": 1000,
#             "Name": "Вон",
#             "Value": 57.1727,
#             "Previous": 56.9017
#         },
#         "JPY": {
#             "ID": "R01820",
#             "NumCode": "392",
#             "CharCode": "JPY",
#             "Nominal": 100,
#             "Name": "Иен",
#             "Value": 53.4601,
#             "Previous": 54.0421
#         }
#     }
# }

# %%
from pprint import pprint # Импортируем функцию pprint()
import json # Импортируем модуль json
currencies = response.json() # Применяем метод json()
pprint(currencies) # Выводим результат на экран
# Out:
# {'Date': '2025-06-24T11:30:00+03:00',
#  'PreviousDate': '2025-06-21T11:30:00+03:00',
#  'PreviousURL': '//www.cbr-xml-daily.ru/archive/2025/06/21/daily_json.js',
#  'Timestamp': '2025-06-23T18:00:00+03:00',
#  'Valute': {'AED': {'CharCode': 'AED',
#                     'ID': 'R01230',
#                     'Name': 'Дирхам ОАЭ',
#                     'Nominal': 1,
#                     'NumCode': '784',
#                     'Previous': 21.3755,
#                     'Value': 21.3185},
#             'AMD': {'CharCode': 'AMD',
#                     'ID': 'R01060',
#                     'Name': 'Армянских драмов',
#                     'Nominal': 100,
#                     'NumCode': '051',
#                     'Previous': 20.3541,
#                     'Value': 20.2788},
#             'AUD': {'CharCode': 'AUD',
#                     'ID': 'R01010',
#                     'Name': 'Австралийский доллар',
#                     'Nominal': 1,
#                     'NumCode': '036',
#                     'Previous': 50.9632,
#                     'Value': 50.201},
#             'AZN': {'CharCode': 'AZN',
#                     'ID': 'R01020A',
#                     'Name': 'Азербайджанский манат',
#                     'Nominal': 1,
#                     'NumCode': '944',
#                     'Previous': 46.1774,
#                     'Value': 46.0543},
#             'BGN': {'CharCode': 'BGN',
#                     'ID': 'R01100',
#                     'Name': 'Болгарский лев',
#                     'Nominal': 1,
#                     'NumCode': '975',
#                     'Previous': 46.0696,
#                     'Value': 46.0947},
#             'BRL': {'CharCode': 'BRL',
#                     'ID': 'R01115',
#                     'Name': 'Бразильский реал',
#                     'Nominal': 1,
#                     'NumCode': '986',
#                     'Previous': 14.3053,
#                     'Value': 14.2469},
#             'BYN': {'CharCode': 'BYN',
#                     'ID': 'R01090B',
#                     'Name': 'Белорусский рубль',
#                     'Nominal': 1,
#                     'NumCode': '933',
#                     'Previous': 26.3596,
#                     'Value': 26.3797},
#             'CAD': {'CharCode': 'CAD',
#                     'ID': 'R01350',
#                     'Name': 'Канадский доллар',
#                     'Nominal': 1,
#                     'NumCode': '124',
#                     'Previous': 57.2002,
#                     'Value': 57.0311},
#             'CHF': {'CharCode': 'CHF',
#                     'ID': 'R01775',
#                     'Name': 'Швейцарский франк',
#                     'Nominal': 1,
#                     'NumCode': '756',
#                     'Previous': 96.2029,
#                     'Value': 95.7119},
#             'CNY': {'CharCode': 'CNY',
#                     'ID': 'R01375',
#                     'Name': 'Юань',
#                     'Nominal': 1,
#                     'NumCode': '156',
#                     'Previous': 10.9021,
#                     'Value': 10.8691},
#             'CZK': {'CharCode': 'CZK',
#                     'ID': 'R01760',
#                     'Name': 'Чешских крон',
#                     'Nominal': 10,
#                     'NumCode': '203',
#                     'Previous': 36.4192,
#                     'Value': 36.121},
#             'DKK': {'CharCode': 'DKK',
#                     'ID': 'R01215',
#                     'Name': 'Датская крона',
#                     'Nominal': 1,
#                     'NumCode': '208',
#                     'Previous': 12.0794,
#                     'Value': 12.0855},
#             'EGP': {'CharCode': 'EGP',
#                     'ID': 'R01240',
#                     'Name': 'Египетских фунтов',
#                     'Nominal': 10,
#                     'NumCode': '818',
#                     'Previous': 15.4942,
#                     'Value': 15.4456},
#             'EUR': {'CharCode': 'EUR',
#                     'ID': 'R01239',
#                     'Name': 'Евро',
#                     'Nominal': 1,
#                     'NumCode': '978',
#                     'Previous': 90.1356,
#                     'Value': 89.8388},
#             'GBP': {'CharCode': 'GBP',
#                     'ID': 'R01035',
#                     'Name': 'Фунт стерлингов',
#                     'Nominal': 1,
#                     'NumCode': '826',
#                     'Previous': 105.4041,
#                     'Value': 105.4206},
#             'GEL': {'CharCode': 'GEL',
#                     'ID': 'R01210',
#                     'Name': 'Лари',
#                     'Nominal': 1,
#                     'NumCode': '981',
#                     'Previous': 28.7868,
#                     'Value': 28.7122},
#             'HKD': {'CharCode': 'HKD',
#                     'ID': 'R01200',
#                     'Name': 'Гонконгских долларов',
#                     'Nominal': 10,
#                     'NumCode': '344',
#                     'Previous': 10.0181,
#                     'Value': 99.9136},
#             'HUF': {'CharCode': 'HUF',
#                     'ID': 'R01135',
#                     'Name': 'Форинтов',
#                     'Nominal': 100,
#                     'NumCode': '348',
#                     'Previous': 22.4585,
#                     'Value': 22.27},
#             'IDR': {'CharCode': 'IDR',
#                     'ID': 'R01280',
#                     'Name': 'Рупий',
#                     'Nominal': 10000,
#                     'NumCode': '360',
#                     'Previous': 47.9311,
#                     'Value': 47.7421},
#             'INR': {'CharCode': 'INR',
#                     'ID': 'R01270',
#                     'Name': 'Индийских рупий',
#                     'Nominal': 100,
#                     'NumCode': '356',
#                     'Previous': 90.6346,
#                     'Value': 90.1902},
#             'JPY': {'CharCode': 'JPY',
#                     'ID': 'R01820',
#                     'Name': 'Иен',
#                     'Nominal': 100,
#                     'NumCode': '392',
#                     'Previous': 54.0421,
#                     'Value': 53.4601},
#             'KGS': {'CharCode': 'KGS',
#                     'ID': 'R01370',
#                     'Name': 'Сомов',
#                     'Nominal': 100,
#                     'NumCode': '417',
#                     'Previous': 89.7674,
#                     'Value': 89.5654},
#             'KRW': {'CharCode': 'KRW',
#                     'ID': 'R01815',
#                     'Name': 'Вон',
#                     'Nominal': 1000,
#                     'NumCode': '410',
#                     'Previous': 56.9017,
#                     'Value': 57.1727},
#             'KZT': {'CharCode': 'KZT',
#                     'ID': 'R01335',
#                     'Name': 'Тенге',
#                     'Nominal': 100,
#                     'NumCode': '398',
#                     'Previous': 15.1095,
#                     'Value': 15.0109},
#             'MDL': {'CharCode': 'MDL',
#                     'ID': 'R01500',
#                     'Name': 'Молдавских леев',
#                     'Nominal': 10,
#                     'NumCode': '498',
#                     'Previous': 45.6702,
#                     'Value': 45.7128},
#             'NOK': {'CharCode': 'NOK',
#                     'ID': 'R01535',
#                     'Name': 'Норвежских крон',
#                     'Nominal': 10,
#                     'NumCode': '578',
#                     'Previous': 78.1375,
#                     'Value': 77.7319},
#             'NZD': {'CharCode': 'NZD',
#                     'ID': 'R01530',
#                     'Name': 'Новозеландский доллар',
#                     'Nominal': 1,
#                     'NumCode': '554',
#                     'Previous': 47.0696,
#                     'Value': 46.5526},
#             'PLN': {'CharCode': 'PLN',
#                     'ID': 'R01565',
#                     'Name': 'Злотый',
#                     'Nominal': 1,
#                     'NumCode': '985',
#                     'Previous': 21.1783,
#                     'Value': 21.0395},
#             'QAR': {'CharCode': 'QAR',
#                     'ID': 'R01355',
#                     'Name': 'Катарский риал',
#                     'Nominal': 1,
#                     'NumCode': '634',
#                     'Previous': 21.5664,
#                     'Value': 21.5089},
#             'RON': {'CharCode': 'RON',
#                     'ID': 'R01585F',
#                     'Name': 'Румынский лей',
#                     'Nominal': 1,
#                     'NumCode': '946',
#                     'Previous': 17.924,
#                     'Value': 17.8006},
#             'RSD': {'CharCode': 'RSD',
#                     'ID': 'R01805F',
#                     'Name': 'Сербских динаров',
#                     'Nominal': 100,
#                     'NumCode': '941',
#                     'Previous': 77.2082,
#                     'Value': 76.7586},
#             'SEK': {'CharCode': 'SEK',
#                     'ID': 'R01770',
#                     'Name': 'Шведских крон',
#                     'Nominal': 10,
#                     'NumCode': '752',
#                     'Previous': 81.417,
#                     'Value': 81.1999},
#             'SGD': {'CharCode': 'SGD',
#                     'ID': 'R01625',
#                     'Name': 'Сингапурский доллар',
#                     'Nominal': 1,
#                     'NumCode': '702',
#                     'Previous': 61.0907,
#                     'Value': 60.6588},
#             'THB': {'CharCode': 'THB',
#                     'ID': 'R01675',
#                     'Name': 'Батов',
#                     'Nominal': 10,
#                     'NumCode': '764',
#                     'Previous': 23.9247,
#                     'Value': 23.73},
#             'TJS': {'CharCode': 'TJS',
#                     'ID': 'R01670',
#                     'Name': 'Сомони',
#                     'Nominal': 10,
#                     'NumCode': '972',
#                     'Previous': 79.2017,
#                     'Value': 79.0831},
#             'TMT': {'CharCode': 'TMT',
#                     'ID': 'R01710A',
#                     'Name': 'Новый туркменский манат',
#                     'Nominal': 1,
#                     'NumCode': '934',
#                     'Previous': 22.429,
#                     'Value': 22.3692},
#             'TRY': {'CharCode': 'TRY',
#                     'ID': 'R01700J',
#                     'Name': 'Турецких лир',
#                     'Nominal': 10,
#                     'NumCode': '949',
#                     'Previous': 19.866,
#                     'Value': 19.7825},
#             'UAH': {'CharCode': 'UAH',
#                     'ID': 'R01720',
#                     'Name': 'Гривен',
#                     'Nominal': 10,
#                     'NumCode': '980',
#                     'Previous': 18.7652,
#                     'Value': 18.6988},
#             'USD': {'CharCode': 'USD',
#                     'ID': 'R01235',
#                     'Name': 'Доллар США',
#                     'Nominal': 1,
#                     'NumCode': '840',
#                     'Previous': 78.5016,
#                     'Value': 78.2923},
#             'UZS': {'CharCode': 'UZS',
#                     'ID': 'R01717',
#                     'Name': 'Узбекских сумов',
#                     'Nominal': 10000,
#                     'NumCode': '860',
#                     'Previous': 62.505,
#                     'Value': 62.6492},
#             'VND': {'CharCode': 'VND',
#                     'ID': 'R01150',
#                     'Name': 'Донгов',
#                     'Nominal': 10000,
#                     'NumCode': '704',
#                     'Previous': 31.3618,
#                     'Value': 31.2819},
#             'XDR': {'CharCode': 'XDR',
#                     'ID': 'R01589',
#                     'Name': 'СДР (специальные права заимствования)',
#                     'Nominal': 1,
#                     'NumCode': '960',
#                     'Previous': 106.9341,
#                     'Value': 106.7602},
#             'ZAR': {'CharCode': 'ZAR',
#                     'ID': 'R01810',
#                     'Name': 'Рэндов',
#                     'Nominal': 10,
#                     'NumCode': '710',
#                     'Previous': 43.5443,
#                     'Value': 43.3719}}}

# %%
pprint(currencies['Valute']['EUR']) # Выводим на экран информацию о валюте евро
# Out:
# {'CharCode': 'EUR',
#  'ID': 'R01239',
#  'Name': 'Евро',
#  'Nominal': 1,
#  'NumCode': '978',
#  'Previous': 90.1356,
#  'Value': 89.8388}

# %%
url = 'https://nplus1.ru/news/2021/10/11/econobel2021' # Определяем адрес страницы
response = requests.get(url)  # Выполняем GET-запрос
print(response.text)  # Выводим содержимое атрибута text
# Out:
# <!DOCTYPE html>
# <html prefix="og: http://ogp.me/ns#" lang="ru">
# <head>
#   <meta charset="utf-8">
#   <meta name="viewport" content="width=device-width, initial-scale=1">
#   <title>Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей</title>
#     <link rel="preload" href="https://staticn1.nplus1.ru/fonts/AeonikPro/AeonikPro-Regular.woff2" as="font" type="font/woff2" crossorigin />
#     <link rel="preload" href="https://staticn1.nplus1.ru/fonts/Spectral/Spectral-Regular.woff" as="font" type="font/woff2" crossorigin />
#   <link href="/front-build/css/main.css?id=842e64708435127ee441c2e86afffea2" rel="stylesheet">
#   <link href="/front-build/css/app.css?id=92673ebe7185ebc42e29fc7294a4c65f" rel="stylesheet">
#
#
#   <link rel="apple-touch-icon" sizes="180x180" href="/apple-touch-icon.png">
#   <link rel="icon" type="image/png" sizes="32x32" href="/favicon-32x32.png">
#   <link rel="icon" type="image/png" sizes="16x16" href="/favicon-16x16.png">
#   <link rel="manifest" href="/site.webmanifest">
#   <link rel="mask-icon" href="/safari-pinned-tab.svg" color="#f26e40">
#   <meta name="msapplication-TileColor" content="#f26e40">
#   <meta name="theme-color" content="#ffffff">
#
#   <link rel="canonical" href="https://nplus1.ru/news/2021/10/11/econobel2021">
#
#   <meta name="yandex-verification" content="8c90b02c84ac3b72"/>
#   <meta name="pmail-verification" content="b419949322895fc9106e24ed01be58ac">
#
#   <!-- Google Tag Manager -->
#
#     <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#
#     new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#
#     j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#
#     'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#
#     })(window,document,'script','dataLayer','GTM-PJWMQBQ');</script>
#
#   <!-- End Google Tag Manager -->
#
#     <!-- HuggingCat -->
#         <script async src="https://huggingcat-web.pages.dev/mywidget.js?static=true"></script>
#         <script>
#             (function (c, a) {
#                 var t = (c[a] = c[a] || []);
#                 t.push(["init"]);
#             })(window, "hc");
#         </script>
#     <!-- End HuggingCat -->
#
#     <!-- Ads -->
#         <script src="/front-build/js/modules/prebid.js?id=ddf9cebd6b4c7a66be2ec26a926d5f3c"></script>
#         <script src="/front-build/js/modules/initPrebidAds.js?id=1884da35da66817a1cc5dbcb173c1347"></script>
#
#         <script src="https://widget.sparrow.ru/js/embed.js"></script>
#     <!-- End Ads -->
#
#
#
#
#
#
#
#   <meta name="description" content="Премия присуждена Дэвиду Карду (David Card) за его вклад в эмпирические исследования экономики рынка труда, а также Джошуа Энгристу (Joshua Angrist) и Гвидо Имбенсу (Guido Imbens) за их вклад в методологию анализа причинно-следственных связей. " />
#
#   <meta property="og:site_name" content="N + 1 — главное издание о науке, технике и технологиях"/>
#   <meta property="og:title" content="Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей"/>
#   <meta property="og:image" content="https://minio.nplus1.ru/app-images/250227/6301a13e6b36b_cover_share.jpg"/>
#   <meta property="og:url" content="https://nplus1.ru/news/2021/10/11/econobel2021"/>
#   <meta property="og:description" content="Премия присуждена Дэвиду Карду (David Card) за его вклад в эмпирические исследования экономики рынка труда, а также Джошуа Энгристу (Joshua Angrist) и Гвидо Имбенсу (Guido Imbens) за их вклад в методологию анализа причинно-следственных связей. "/>
#   <meta property="og:type" content="article"/>
#
#     <meta itemprop="datePublished" content="2021-10-11"/>
#   <!-- amp page -->
#   <link rel="amphtml" href="https://nplus1.ru/news/2021/10/11/econobel2021/amp">
#
#
#
#   <meta itemprop="datePublished" content="2021-10-11"/>
#
#
#
#       <meta name="mediator_author" content="Илья Ферапонтов"/>
#     <meta name="author" content="Илья Ферапонтов"/>
#
#   <meta name="copyright" content=""/>
#
#       <script type="application/ld+json">
#     {
#       "@context": "https://schema.org",
#       "@type": "NewsArticle",
#       "mainEntityOfPage": {
#         "@type": "WebPage",
#         "@id": "https://nplus1.ru/news/2021/10/11/econobel2021"
#       },
#       "headline": "Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей",
#       "description": "",
#             "image": "https://minio.nplus1.ru/app-images/250227/6301a13e6b36b_cover_share.jpg",
#
#
#
#
#           "author": {
#         "@type": "Person",
#         "name": "Илья Ферапонтов",
#                 "image": "https://minio.nplus1.ru/app-images/793327/f7199286c33e5d744656c65cc770eb5e.jpg",
#                 "url": "https://nplus1.ru/author/ilya-ferapontov"
#         },
#
#         "publisher": {
#       "@type": "Organization",
#       "name": "N+1",
#       "logo": {
#         "@type": "ImageObject",
#         "url": "https://minio.nplus1.ru/app-images/250227/6301a13e6b36b_cover_share.jpg"
#       }
#     },
#     "datePublished": "2021-10-11",
#       "dateModified": "2021-10-11"
#     }
#
#
#
#     </script>
#
#
#
#
#   <meta name="twitter:card" content="summary_large_image">
#   <meta name="twitter:site" content="@nplusodin"/>
#   <meta name="twitter:title" content="Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей"/>
#   <meta name="twitter:description" content="Премия присуждена Дэвиду Карду (David Card) за его вклад в эмпирические исследования экономики рынка труда, а также Джошуа Энгристу (Joshua Angrist) и Гвидо Имбенсу (Guido Imbens) за их вклад в методологию анализа причинно-следственных связей. "/>
#   <meta name="twitter:image" content="https://minio.nplus1.ru/app-images/250227/6301a13e6b36b_cover_share.jpg"/>
#
#   <link rel='alternate' type='application/rss+xml' title='RSS' href='https://nplus1.ru/rss'>
#
#
#
#
#
#
#
#
#
#
#
#
#
# </head>
# <body class="antialiased">
#
# <!-- Top.Mail.Ru counter -->
#
# <script type="text/javascript">
#
# var tmr = window.tmr || (window._tmr = []);
#
# _tmr.push({id: "3377932", type: "pageView", start: (new Date()).getTime()});
#
# (function (d, w, id) {
#
#   if (d.getElementById(id)) return;
#
#   var ts = d.createElement("script"); ts.type = "text/javascript"; ts.async = true; ts.id = id;
#
#   ts.src = "https://top-fwz1.mail.ru/js/code.js";
#
#   var f = function () {var s = d.getElementsByTagName("script")[0]; s.parentNode.insertBefore(ts, s);};
#
#   if (w.opera == "[object Opera]") { d.addEventListener("DOMContentLoaded", f, false); } else { f(); }
#
# })(document, window, "tmr-code");
#
# </script>
#
# <noscript><div><img src="https://top-fwz1.mail.ru/counter?id=3377932;js=na" style="position:absolute;left:-9999px;" alt="Top.Mail.Ru" /></div></noscript>
#
# <!-- /Top.Mail.Ru counter -->
# <!-- Google Tag Manager (noscript) -->
#   <noscript><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-PJWMQBQ"
#   height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
#
# <div id="appfront" class="font-aeonik text-main-black flex flex-col min-h-screen pt-15 bg-light-gray">
#   <header class="bg-light-gray fixed h-15 left-0 top-0 w-full z-50"
#         data-ref-header
#         ref="headerRef">
#
#       <div id="progressBar" class="absolute bg-main-gray/5 bottom-0 left-0 top-0" style="z-index: -1"></div>
#
#   <div class="border-b border-main-gray h-full">
#     <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto flex justify-between items-center h-full"
#          data-ref-header-container
#          ref="headerContainerRef">
#
#       <button aria-label="Go" data-ref-header-menu-btn
#               ref="headerMenuBtnRef"
#               id="topMenuBtn"
#               @click="menuOpen"
#               class="w-7.5 h-7.5">
#         <template v-if="isOpenDesktopMenu || isOpenMobileMenu">
#           <svg class="w-full h-full">
#             <use xlink:href="#n1_cross_menu"></use>
#           </svg>
#         </template>
#         <template v-else>
#           <svg class="w-full h-full">
#             <use xlink:href="#n1_burger"></use>
#           </svg>
#         </template>
#       </button>
#
#       <div>
#                   <a href="/">
#                         <img loading="lazy" src="https://staticn1.nplus1.ru/image-new/logo.svg" height="23" width="57" alt="as">
#                       </a>
#               </div>
#
#       <a href="/search" class="w-7.5 h-7.5">
#         <svg class="w-full h-full">
#           <use xlink:href="#n1_pupa"></use>
#         </svg>
#       </a>
#     </div>
#   </div>
#
#   <nav v-if="isOpenDesktopMenu" id="navMenu" class="relative bg-light-gray max-h-0 n1_top_nav overflow-hidden"
#        :style="stylesNavDesktop">
#     <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto h-full flex flex-col overflow-y-auto">
#       <div class="py-12 mb-12 border-b border-gray-2 text-18 grid grid-cols-flow lg:grid-cols-12 gap-x-5 md:gap-x-9">
#
#
#         <!--
#         <a @click.native="menuClose"
#            class="col-span-3 flex gap-x-2 lg:gap-x-5 items-center hover:text-main transition-colors duration-75"
#            href="/lk">
#           <svg class="h-10 lg:h-12 w-10 lg:w-12 shrink-0">
#             <use xlink:href="#n1_person"></use>
#           </svg>
#           <span>Личный кабинет</span>
#         </a>
#         -->
#
#         <a class="col-span-3 lg:col-span-2 col-start-7 lg:col-start-9 flex items-center hover:text-main transition-colors duration-75"
#            href="https://offline.nplus1.ru/">N + offline</a>
#         <a class="col-span-3 lg:col-span-2 col-start-10 lg:col-start-11 flex items-center hover:text-main transition-colors duration-75"
#            href="https://nplus.pro/">N + production</a>
#       </div>
#       <div class="grid grid-cols-12 gap-x-5 gap-y-5 md:gap-y-9 pb-6">
#         <div class="col-span-6 md:col-span-3 text-20 lg:text-26 xl:text-34 font-spectral flex flex-col gap-y-3">
#
#                                     <a
#
#                                 href="https://nplus1.ru/about" class="hover:text-main transition-colors duration-75"
#               >
#                 О нас
#               </a>
#                                                 <a
#
#                  target="_blank"                 href="https://nplus1.ru/difficult" class="hover:text-main transition-colors duration-75"
#               >
#                 Сложность
#               </a>
#                                                 <a
#
#                  target="_blank"                 href="https://nplus1.ru/adv" class="hover:text-main transition-colors duration-75"
#               >
#                 Рекламодателям
#               </a>
#                                                 <a
#
#                  target="_blank"                 href="https://nplus1.ru/blog/2022/04/01/samotek" class="hover:text-main transition-colors duration-75"
#               >
#                 Авторам
#               </a>
#
#         </div>
#
#                   <div class="col-span-6 md:col-span-3 text-18 lg:text-24 xl:text-32 text-main flex flex-col gap-y-3">
#                           <a class="hover:underline transition-colors duration-75"
#                  href="https://nplus1.ru/search?tags=946">Игры</a>
#                           <a class="hover:underline transition-colors duration-75"
#                  href="https://nplus1.ru/search?tags=869">Физика</a>
#                           <a class="hover:underline transition-colors duration-75"
#                  href="https://nplus1.ru/search?tags=874">Зоология</a>
#                           <a class="hover:underline transition-colors duration-75"
#                  href="https://nplus1.ru/search?tags=880">Астрономия</a>
#                           <a class="hover:underline transition-colors duration-75"
#                  href="https://nplus1.ru/search?tags=768">Генетика</a>
#                           <a class="hover:underline transition-colors duration-75"
#                  href="https://nplus1.ru/search?tags=890">Математика</a>
#                       </div>
#                   <div class="col-span-6 md:col-span-3 text-18 lg:text-24 xl:text-32 text-main flex flex-col gap-y-3">
#                           <a class="hover:underline transition-colors duration-75"
#                  href="https://nplus1.ru/search?tags=871">Космонавтика</a>
#                           <a class="hover:underline transition-colors duration-75"
#                  href="https://nplus1.ru/search?tags=876">Археология</a>
#                           <a class="hover:underline transition-colors duration-75"
#                  href="https://nplus1.ru/search?tags=775">Нейронауки</a>
#                           <a class="hover:underline transition-colors duration-75"
#                  href="https://nplus1.ru/search?tags=767">На мышах</a>
#                           <a class="hover:underline transition-colors duration-75"
#                  href="https://nplus1.ru/search?tags=771">Звук</a>
#                           <a class="hover:underline transition-colors duration-75"
#                  href="https://nplus1.ru/search?tags=772">Красота</a>
#                       </div>
#                   <div class="col-span-6 md:col-span-3 text-18 lg:text-24 xl:text-32 text-main flex flex-col gap-y-3">
#                           <a class="hover:underline transition-colors duration-75"
#                  href="https://nplus1.ru/search?tags=778">Научные закрытия</a>
#                           <a class="hover:underline transition-colors duration-75"
#                  href="https://nplus1.ru/search?tags=917">ИИ спешит на помощь</a>
#                           <a class="hover:underline transition-colors duration-75"
#                  href="https://nplus1.ru/search?tags=918">Когда рассеется дым</a>
#                           <a class="hover:underline transition-colors duration-75"
#                  href="https://nplus1.ru/search?tags=824">Книжная полка</a>
#                       </div>
#
#       </div>
#       <div class="py-12 mt-auto border-t border-gray-2 text-18 grid grid-cols-12 gap-x-5 md:gap-x-9">
#         <ul class="flex gap-2.5">
#           <li>
#             <a class="hover:text-main" href="https://t.me/nplusone" target="_blank">
#               <svg class="w-12 h-12">
#                 <use xlink:href="#n1_tg"></use>
#               </svg>
#             </a>
#           </li>
#           <li>
#             <a class="hover:text-main" href="https://vk.com/nplusone" target="_blank">
#               <svg class="w-12 h-12">
#                 <use xlink:href="#n1_vk"></use>
#               </svg>
#             </a>
#           </li>
#           <li>
#             <a class="hover:text-main" href="https://ok.ru/nplus1" target="_blank">
#               <svg class="w-12 h-12">
#                 <use xlink:href="#n1_ok"></use>
#               </svg>
#             </a>
#           </li>
#           <li class="w-12">
#             <a class="hover:text-main" href="https://twitter.com/nplusodin" target="_blank">
#               <svg class="w-12 h-12">
#                 <use xlink:href="#n1_tw"></use>
#               </svg>
#             </a>
#           </li>
#         </ul>
#       </div>
#     </div>
#   </nav>
#
#   <nav v-if="isOpenMobileMenu" id="mobNavMenu" class="relative bg-white max-h-0 n1_top_nav overflow-hidden"
#        :style="stylesNavMobile">
#     <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto h-full flex flex-col overflow-y-auto">
#
#       <div class="text-30 font-spectral flex flex-col gap-y-5 mb-10 mt-10">
#                                   <a
#
#                                 href="https://nplus1.ru/about" class="hover:text-main transition-colors duration-75"
#               >
#                 О нас
#               </a>
#                                                 <a
#
#                  target="_blank"                 href="https://nplus1.ru/difficult" class="hover:text-main transition-colors duration-75"
#               >
#                 Сложность
#               </a>
#                                                 <a
#
#                  target="_blank"                 href="https://nplus1.ru/adv" class="hover:text-main transition-colors duration-75"
#               >
#                 Рекламодателям
#               </a>
#                                                 <a
#
#                  target="_blank"                 href="https://nplus1.ru/blog/2022/04/01/samotek" class="hover:text-main transition-colors duration-75"
#               >
#                 Авторам
#               </a>
#                                                                                                                                                                 </div>
#       <div class="text-28 text-main flex flex-col gap-y-2.5 mb-10">
#
#                   <a class="hover:underline transition-colors duration-75"
#               href="https://nplus1.ru/search?tags=946">Игры
#           </a>
#                   <a class="hover:underline transition-colors duration-75"
#               href="https://nplus1.ru/search?tags=869">Физика
#           </a>
#                   <a class="hover:underline transition-colors duration-75"
#               href="https://nplus1.ru/search?tags=874">Зоология
#           </a>
#                   <a class="hover:underline transition-colors duration-75"
#               href="https://nplus1.ru/search?tags=880">Астрономия
#           </a>
#                   <a class="hover:underline transition-colors duration-75"
#               href="https://nplus1.ru/search?tags=768">Генетика
#           </a>
#                   <a class="hover:underline transition-colors duration-75"
#               href="https://nplus1.ru/search?tags=890">Математика
#           </a>
#                   <a class="hover:underline transition-colors duration-75"
#               href="https://nplus1.ru/search?tags=871">Космонавтика
#           </a>
#                   <a class="hover:underline transition-colors duration-75"
#               href="https://nplus1.ru/search?tags=876">Археология
#           </a>
#                   <a class="hover:underline transition-colors duration-75"
#               href="https://nplus1.ru/search?tags=775">Нейронауки
#           </a>
#                   <a class="hover:underline transition-colors duration-75"
#               href="https://nplus1.ru/search?tags=767">На мышах
#           </a>
#                   <a class="hover:underline transition-colors duration-75"
#               href="https://nplus1.ru/search?tags=771">Звук
#           </a>
#                   <a class="hover:underline transition-colors duration-75"
#               href="https://nplus1.ru/search?tags=772">Красота
#           </a>
#                   <a class="hover:underline transition-colors duration-75"
#               href="https://nplus1.ru/search?tags=778">Научные закрытия
#           </a>
#                   <a class="hover:underline transition-colors duration-75"
#               href="https://nplus1.ru/search?tags=917">ИИ спешит на помощь
#           </a>
#                   <a class="hover:underline transition-colors duration-75"
#               href="https://nplus1.ru/search?tags=918">Когда рассеется дым
#           </a>
#                   <a class="hover:underline transition-colors duration-75"
#               href="https://nplus1.ru/search?tags=824">Книжная полка
#           </a>
#
#       </div>
#       <div class="max-w-full flex py-5 border-t border-gray-2">
#         <div class="flex gap-x-5 overflow-x-auto">
#
#           <a class="hover:text-main whitespace-nowrap" href="https://offline.nplus1.ru/">N + offline</a>
#           <a class="hover:text-main whitespace-nowrap" href="https://nplus.pro/">N + production</a>
#         </div>
#       </div>
#       <div class="pt-5 pb-10 border-t border-gray-2 text-18">
#         <ul class="flex gap-2.5">
#           <li>
#             <a class="hover:text-main" href="https://t.me/nplusone" target="_blank">
#               <svg class="w-10 h-10">
#                 <use xlink:href="#n1_tg"></use>
#               </svg>
#             </a>
#           </li>
#           <li>
#             <a class="hover:text-main" href="https://vk.com/nplusone" target="_blank">
#               <svg class="w-10 h-10">
#                 <use xlink:href="#n1_vk"></use>
#               </svg>
#             </a>
#           </li>
#           <li>
#             <a class="hover:text-main" href="https://ok.ru/nplus1" target="_blank">
#               <svg class="w-10 h-10">
#                 <use xlink:href="#n1_ok"></use>
#               </svg>
#             </a>
#           </li>
#           <li class="w-12">
#             <a class="hover:text-main" href="https://twitter.com/nplusodin" target="_blank">
#               <svg class="w-10 h-10">
#                 <use xlink:href="#n1_tw"></use>
#               </svg>
#             </a>
#           </li>
#         </ul>
#       </div>
#
#     </div>
#   </nav>
#
# </header>
#
#
#   <app-heading-nav></app-heading-nav>
#
#   <section class="mb-15 md:mb-20">
#     <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto grid grid-cols-6 md:grid-cols-12 gap-x-5 md:gap-x-7.5 relative"
#          data-heading-wrap>
#
#       <!--tags-->
#
#               <div class="relative flex-wrap col-span-6 md:col-span-12 lg:col-span-2 lg:row-span-3 mt-5 -mb-2.5 lg:-mb-0 lg:mt-10 content-start mr-9">
#           <div class="flex flex-wrap lg:mb-10 gap-2 text-tags xl:pr-9">
#
#                           <span class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center">
#                 <span class="group-hover:text-main transition-colors duration-75">13:04</span>
#               </span>
#
#             <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center"
#                href="/news/2021/10/11">
#               <span class="group-hover:text-main transition-colors duration-75">11.10.21</span>
#             </a>
#             <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center"
#                href="/material/difficulty/1">
#               <svg class="w-4 h-4 mr-1 group-hover:text-main transition-colors duration-75 stroke-current">
#                 <use xlink:href="#n1_star"></use>
#               </svg>
#               <span class="group-hover:text-main transition-colors duration-75">1.1</span>
#             </a>
#
#                                           <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center"
#                    href="https://nplus1.ru/search?tags=898">
#                   <span class="group-hover:text-main transition-colors duration-75">Экономика</span>
#                 </a>
#
#                                           <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center"
#                    href="https://nplus1.ru/search?tags=785">
#                   <span class="group-hover:text-main transition-colors duration-75">Нобелевская премия</span>
#                 </a>
#
#           </div>
#           <div class="hidden lg:flex items-center gap-x-2">
#             <a href="https://nplus1.ru/material-print/30917" target="_blank" class="group">
#               <svg class="group-hover:text-main transition-colors duration-75 stroke-current" width="22"
#                    height="30" viewBox="0 0 22 30" fill="none" xmlns="http://www.w3.org/2000/svg">
#                 <rect x="0.5" y="0.5" width="21" height="29"/>
#                 <line x1="4" y1="7.5" x2="18" y2="7.5"/>
#                 <line x1="4" y1="21.5" x2="18" y2="21.5"/>
#                 <line x1="4" y1="14.5" x2="18" y2="14.5"/>
#               </svg>
#             </a>
#
#             <app-copy-material
#                     link="https://nplus1.ru/news/2021/10/11/econobel2021"
#                     type="full-2"
#             ></app-copy-material>
#           </div>
#
#           <div class="w-full flex flex-col mt-5">
#
#
#                       </div>
#
#           <div class="header-bidding-ad-container header-bidding-ad-container--left hidden lg:hidden flex-col mt-5 w-160 h-600">
#             <app-header-bidding-ad
#                 :id="898517"
#                 width="160px"
#                 height="600px"
#                 :close-button="false"
#             ></app-header-bidding-ad>
#           </div>
#         </div>
#
#       <!--dotes menu mobile-->
#       <template v-if="isMobile">
#         <button
#                 @click="openMobileDotsMenu"
#                 class="absolute flex right-5 top-5 z-30 text-main-black" >
#           <svg xmlns="http://www.w3.org/2000/svg" width="30" height="30" viewBox="0 0 30 30" fill="none"
#                class="fill-current">
#             <path fill-rule="evenodd" clip-rule="evenodd"
#                   d="M17 6C17 6.55228 16.5523 7 16 7H15C14.4477 7 14 6.55228 14 6V5C14 4.44772 14.4477 4 15 4H16C16.5523 4 17 4.44772 17 5V6ZM17 23C17 23.5523 16.5523 24 16 24H15C14.4477 24 14 23.5523 14 23V22C14 21.4477 14.4477 21 15 21H16C16.5523 21 17 21.4477 17 22V23ZM14 14.5C14 15.0523 14.4477 15.5 15 15.5H16C16.5523 15.5 17 15.0523 17 14.5V13.5C17 12.9477 16.5523 12.5 16 12.5H15C14.4477 12.5 14 12.9477 14 13.5V14.5Z"/>
#           </svg>
#         </button>
#
#         <div ref="mobileDotsMenuRef"
#              :class="{
#            'transition-transform flex items-center gap-x-7.5 absolute top-0 right-0 w-full px-6 md:px-8 h-20 bg-white z-30 justify-end bg-light-gray':true,
#            '-translate-x-full': !isOpenMobileDotsMenu,
#            '-translate-x-0': isOpenMobileDotsMenu
#            }">
#
#           <app-copy-material
#                   link="https://nplus1.ru/news/2021/10/11/econobel2021"
#                   type="mobile"
#           ></app-copy-material>
#
#           <button aria-label="Go" class="group">
#             <svg class="group-focus:text-main transition-colors duration-75 stroke-current"
#                  xmlns="http://www.w3.org/2000/svg" width="30" height="40" viewBox="0 0 30 40" fill="none">
#               <path d="M14.3303 26.2967L0.5 38.8697V0.5H28.8333V38.8697L15.003 26.2967L14.6667 25.9909L14.3303 26.2967Z"/>
#             </svg>
#           </button>
#
#           <button aria-label="Go" class="group">
#             <svg class="group-focus:text-main transition-colors duration-75 stroke-current"
#                  xmlns="http://www.w3.org/2000/svg" width="30" height="40" viewBox="0 0 30 40" fill="none">
#               <rect x="0.833984" y="0.5" width="28.3333" height="39"/>
#               <line x1="5.66732" y1="10.1665" x2="24.334" y2="10.1665"/>
#               <line x1="5.66732" y1="28.8335" x2="24.334" y2="28.8335"/>
#               <line x1="5.66732" y1="19.5" x2="24.334" y2="19.5"/>
#             </svg>
#           </button>
#
#         </div>
#       </template>
#
#       <!-- main image -->
#             <!--main-->
#
#       <div class="col-span-6 md:col-span-8 lg:col-span-7 lg:col-start-3 row-span-2 lg:border-l lg:border-gray-200 xl:-ml-9 lg:pl-9 mt-10">
#         <div class="flex flex-col">
#
#
#           <h1 class="text-34 md:text-42 xl:text-52 break-words mb-6">
#             Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей
#           </h1>
#
#
#
#
#             <div class="text-14 mb-5 sm:mb-12 flex flex-wrap">
#
#
#                 <span class="whitespace-nowrap">
#
#                   <a class="underline" href="/author/ilya-ferapontov">Илья Ферапонтов</a>
#                 </span>
#
#
#
#
#             </div>
#
#           <div data-lmb-0 class="mb-14">
#
#
#
#
#                                                             <BaseGalleryMain :gid="18670"></BaseGalleryMain>
#
#                      <div></div>
#
#
#
#                                   <div class="n1_material text-18"><p class="mb-6">Премия Шведского национального банка по экономическим наукам памяти Альфреда Нобеля за 2021 год присуждена Дэвиду Карду (David Card) за его вклад в эмпирические исследования экономики рынка труда, а также Джошуа Энгристу (Joshua Angrist) и Гвидо Имбенсу (Guido Imbens) за их вклад в методологию анализа причинно-следственных связей. Прямая трансляция церемонии объявления лауреатов <a href="https://www.nobelprize.org/" target="_blank">шла</a> на официальном сайте Нобелевской премии.</p></div>
#
#
#                                             <div class="block md:hidden col-span-6 mb-6">
#                             <div class="w-full" data-ref-sidebar></div>
#
#                                                                                                                                                                                     </div>
#
#
#
#
#
#
#                                                             <BaseGalleryMain :gid="1381"></BaseGalleryMain>
#
#                      <div></div>
#
#
#
#                                   <div class="n1_material text-18"><p class="mb-6">Премия по экономике, в отличие от Нобелевских премий по физиологии и медицине, физике, химии и литературе, а также премии мира, была учреждена не самим Альфредом Нобелем, а Банком Швеции в 1968 году. Ее размер равен размеру остальных премий.</p></div>
#
#
#
#
#
#                                   <div class="n1_material text-18"><p class="mb-6">Лауреаты этого года награждены за их исследования причинно-следственных связей в области социальных наук. В частности, Дэвид Кард из университета Калифорнии в Беркли начиная с 1990-х годов исследовал, как именно на рынок труда влияют изменения минимальных зарплат, уровень иммиграции и образовательный уровень населения. Полученные им результаты, в частности, указывали, что повышение уровня минимальных зарплат не обязательно влечет за собой сокращение количества рабочих мест.</p></div>
#
#
#
#
#
#                                   <div class="n1_material text-18"><p class="mb-6">Два других лауреата - Джошуа Ангрист из Массачусетского технологического института и Гвидо Имбенс из Стэнфордского университета исследовали, как можно установить наличие причинно-следственных связей в естественных экспериментах, связанных с поисками отношения между уровнем образования и доходами.</p></div>
#
#
#
#
#
#                                   <div class="n1_material text-18"><p class="mb-6">Компания Clarivate, которая составляет списки потенциальных нобелевских лауреатов на основе наукометрических данных, в 2021 году <a href="https://nplus1.ru/blog/2021/09/22/clarivate-prognosis-2021" target="_blank">предположила</a>, что в экономической номинации премию могут присудить Дэвиду Одречу (David Audretsch) и Дэвиду Тису (David Teece) за исследование инноваций.</p></div>
#
#
#
#
#
#                                   <div class="n1_material text-18"><p class="mb-6">Кроме того, в списке этого года были Джоэл Мокир (Joel Mokyr), который исследует культурные истоки промышленной революции, а также Кармен Рейнхарт (Carmen Reinhart) и Кеннет Рогофф (Kenneth Rogoff) — авторы гипотезы «90-процентного порога»., согласно которой, когда внешний долг государства достигает 90 процентов от ВВП, скорость роста ВВП падает вдвое.</p></div>
#
#
#
#
#
#                                   <div class="n1_material text-18"><p class="mb-6">В 2020 году премию по экономике присудили Полу Милгрому и Роберту Уилсону за развитие теории аукционов и изобретение новых форматов аукционов. Лауреаты исследовали, как работают аукционы, и разрабатывали новые форматы проведения аукционов для продажи товаров и услуг, которые трудно продавать с помощью традиционных методов. Читайте об их работах в нашем материале <a href="https://nplus1.ru/material/2020/10/13/nobel-econ-2020" target="_blank">«Тонкости молотка»</a>.</p></div>
#
#
#
#
#
#                                   <div class="n1_material text-18"><p class="mb-6">В 2019 году премии памяти Нобеля по экономике были удостоены Абхиджит Банерджи, Эстер Дюфло и Майкл Кремер — «за экспериментальный подход к искоренению глобальной бедности». Подробнее о заслугах лауреатов можно прочесть в нашем материале <a href="https://nplus1.ru/material/2019/10/14/nobeleconomic" target="_blank" title="Link: https://nplus1.ru/material/2019/10/14/nobeleconomic">«Опыты на бедных»</a>. В 2018 года награда была присуждена Уильяму Нордхаусу за «интеграцию изменения климата в долгосрочный макроэкономический анализ» и Полу Ромеру за «интеграцию технологических инноваций в долгосрочный макроэкономический анализ». Об их работах можно прочитать в материале <a href="https://nplus1.ru/material/2018/10/08/econobel-2018" target="_blank">«Почем знания для природы»</a>.</p></div>
#
#
#
#
#
#                                   <div class="n1_material text-18"><p class="mb-6"><i>Сергей Кузнецов</i></p></div>
#
#
#
#
#                                       </div>
#
#
#           <div class="text-18">
#
#
#
#             <div class="text-20 font-spectral text-main-gray leading-none" v-if="!isMobile">
#               Нашли опечатку? Выделите фрагмент и нажмите Ctrl+Enter.
#             </div>
#
#           </div>
#
#         </div>
#       </div>
#
#       <!--right sidebar-->
#
#       <div class="block col-span-6 md:col-span-4 lg:col-span-3 row-span-3 mt-10">
#             <div class="w-full" data-ref-sidebar></div>
#
#
#
#
#                     <div class="header-bidding-ad-container header-bidding-ad-container--right hidden md:hidden flex-col mt-5 w-300 h-600">
#                         <app-header-bidding-ad
#                             :id="898516"
#                             width="300px"
#                             height="600px"
#                             :close-button="false"
#                         ></app-header-bidding-ad>
#                     </div>
#
#
#                   </div>
#     </div>
#   </section>
#
#
#       <section class="mb-9 md:mb-20">
#
#
#   <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto grid grid-cols-6 md:grid-cols-12 gap-x-5 md:gap-x-9">
#
#     <!--tags-->
#
#           <div class="flex-wrap col-span-6 md:col-span-12 lg:col-span-2 -mb-2.5 lg:-mb-0 content-start">
#         <div class="flex flex-wrap lg:mb-10 gap-2 text-tags xl:pr-9">
#
#
#           <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center"
#              href="/blog/2023/07/05">
#             <span class="group-hover:text-main transition-colors duration-75">05.07.23</span>
#           </a>
#
#           <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center"
#              href="/material/difficulty/1">
#             <svg class="w-4 h-4 mr-1 group-hover:text-main transition-colors duration-75 stroke-current">
#               <use xlink:href="#n1_star"></use>
#             </svg>
#             <span class="group-hover:text-main transition-colors duration-75">1.1</span>
#           </a>
#
#                                     <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center"
#                  href="https://nplus1.ru/search?tags=817">
#                 <span class="group-hover:text-main transition-colors duration-75">История</span>
#               </a>
#                           <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center"
#                  href="https://nplus1.ru/search?tags=898">
#                 <span class="group-hover:text-main transition-colors duration-75">Экономика</span>
#               </a>
#
#
#         </div>
#         <div class="hidden lg:flex items-center gap-x-2">
#
#
#
#
#
#
#
#
#                       <a href="https://nplus1.ru/material-print/65501" aria-label="Go" class="group">
#               <svg class="group-hover:text-main transition-colors duration-75 stroke-current" width="22" height="30"
#                    viewBox="0 0 22 30" fill="none" xmlns="http://www.w3.org/2000/svg">
#                 <rect x="0.5" y="0.5" width="21" height="29"></rect>
#                 <line x1="4" y1="7.5" x2="18" y2="7.5"></line>
#                 <line x1="4" y1="21.5" x2="18" y2="21.5"></line>
#                 <line x1="4" y1="14.5" x2="18" y2="14.5"></line>
#               </svg>
#             </a>
#
#
#
#
#
#
#                       <app-copy-material
#                     link="https://nplus1.ru/blog/2023/07/05/his-times-his-crimes"
#                     type="full-2"
#             ></app-copy-material>
#
#         </div>
#       </div>
#
#     <!--main image  -->
#
#
#
#     <!--main-->
#
#     <div class="col-span-6 md:col-span-8 lg:col-span-7 lg:col-start-3 row-span-2 lg:border-l lg:border-gray-200 xl:-ml-9 lg:pl-9 mt-10 lg:mt-0 ">
#       <div class="flex flex-col">
#
#         <div class="text-34 md:text-42 xl:text-52 break-words">
#           «Уинстон Черчилль: его эпоха, его преступления»
#         </div>
#
#                   <p class="text-36 md:text-44 xl:text-54 font-spectral text-main-gray mb-6">Критический взгляд на фигуру «величайшего британца в истории»</p>
#
#                   <div class="grid grid-cols-6 sm:grid-cols-7 items-center text-14 pt-1.5 sm:pt-6 mb-10 sm:mb-13 gap-y-10 gap-x-5 md:gap-x-9">
#             <div class="col-span-6 sm:col-span-3 gap-x-5 flex items-center">
#                               <a class="shrink-0 w-12 h-12" href="/author/alpina-non-fiksn">
#                   <img src="https://minio.nplus1.ru/app-images/694729/1ccc6e9960399e0551870d97fc98b306.jpg"
#                        loading="lazy"
#                        class="w-full h-full object-cover" alt="Альпина нон-фикшн">
#                 </a>
#                             <a class="text-14 flex flex-col" href="/author/alpina-non-fiksn">
#                 <span class="mb-0.5">
#
#                                     Альпина нон-фикшн
#                 </span>
#                 <span class="font-spectral text-main-gray">Научно-популярное издательство</span>
#               </a>
#             </div>
#             <div class="col-span-6 sm:col-span-3 lg:col-start-5">
#               <p class="font-spectral text-main-gray">Мнение редакции может не совпадать с&nbsp;мнением автора</p>
#             </div>
#           </div>
#
#         <div class="text-14 pt-4 sm:pt-6 mb-10 sm:mb-12 flex flex-wrap">
#
#             <a class="underline whitespace-nowrap"
#                href="/author/alpina-non-fiksn">Альпина нон-фикшн</a>
#
#
#                   </div>
#
#         <div class="n1_material text-18" id="read-next-2">
#           <p class="mb-6">Уинстон Черчилль известен прежде всего как политик и полководец, возглавивший Великобританию в войне с нацизмом. Однако многим он также запомнился как сторонник империализма и воплощение правящего класса, который боролся с рабочими и подавлял всякое инакомыслие. В книге «Уинстон Черчилль: его эпоха, его преступления» (издательство «Альпина нон-фикшн»), переведенной на русский язык Максимом Коробовым, историк Тарик Али рассказывает о неприглядных эпизодах политической карьеры Черчилля, в том числе военных ошибках, допущенных в ходе Первой мировой войны, борьбе с ирландскими националистами и голоде в Бенгалии. Предлагаем вам ознакомиться с фрагментом, посвященным тому, как действия правительства Великобритании привели к крупнейшей забастовке в истории британского рабочего движения.</p>
#         </div>
#
#         <div class="mt-5 md:mt-6 mb-5">
#           <a class="inline-flex justify-center bg-main w-full py-4"
#              href="https://nplus1.ru/blog/2023/07/05/his-times-his-crimes">
#             <span class="text-white text-22 md:text-24">Читать дальше</span>
#           </a>
#         </div>
#
#       </div>
#     </div>
#
#   </div>
# </section>
#
#
#
#
#   <div class="mb-5 w-full overflow-hidden">
#     <app-material-slider-carousel :const-container="constContainer" :const-start-container="constStartContainer">
#   <template v-slot:default="slotProps">
#
#
#   </template>
# </app-material-slider-carousel>
#   </div>
#
#   <div class="exchange-ad-container mb-5">
#         <app-exchange-ad
#             script-url="/front-build/js/modules/initExchangeAds.js?id=d41d8cd98f00b204e9800998ecf8427e"
#             data-key="545b0632c32e67738ab0b6219c3153a6"
#         ></app-exchange-ad>
#   </div>
#
#   <app-typo-modal :width="constContainer" material-id="30917"></app-typo-modal>
#
#
#
#
#   <footer class="mt-auto relative">
#   <app-cookie></app-cookie>
#
#   <div class="bg-main-black pb-15 sm:py-10 md:py-12 xl:py-15">
#     <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto grid grid-cols-6 sm:grid-cols-12 gap-x-5 sm:gap-x-9">
#       <div class="order-1 col-span-6 sm:col-span-3 lg:col-span-2 mb-12 sm:mb-10">
#         <div>
#           <svg class="n1_footer_logo" xmlns="http://www.w3.org/2000/svg" viewBox="0 0 148 60" fill="none">
#             <path d="M0 60V0H11.6065L36.9417 37.8V0H49.5723V60H37.8804L12.5339 22.2V60H0Z" fill="#F9F9F9"></path>
#             <path d="M75.0234 11.144H85.9471V24.8583H98.9191V35.0583H85.9471V48.8583H75.0234V35.0583H62.1367V24.8583H75.0234V11.144Z"
#                   fill="#F9F9F9"></path>
#             <path d="M136.304 49.5429H147.999V60H111.473V49.5429H124.103V21.8571C123.118 22.0352 122.118 22.1213 121.116 22.1143H111.643V11.9143H119.751C122.823 11.9143 124.274 9.08572 124.274 5.82858V0H136.307L136.304 49.5429Z"
#                   fill="#F9F9F9"></path>
#           </svg>
#         </div>
#       </div>
#       <ul class="order-2 sm:order-3 col-span-6 sm:col-span-3 lg:col-span-2 row-span-2 text-26 sm:text-16 text-light-gray font-spectral font-light mb-10 lg:mb-0 gap-y-1.5 sm:gap-y-4 flex flex-col">
#                               <li>
#               <a target="_blank" href="https://nplus1.ru/about"
#                  class="transition-colors duration-75 hover:text-main">О нас</a>
#             </li>
#                                         <li>
#               <a target="_blank" href="https://nplus1.ru/difficult"
#                  class="transition-colors duration-75 hover:text-main">Сложность</a>
#             </li>
#                                         <li>
#               <a target="_blank" href="https://nplus1.ru/adv"
#                  class="transition-colors duration-75 hover:text-main">Рекламодателям</a>
#             </li>
#                                         <li>
#               <a target="_blank" href="https://nplus1.ru/blog/2022/04/01/samotek"
#                  class="transition-colors duration-75 hover:text-main">Авторам</a>
#             </li>
#                                                                                                                                     </ul>
#       <div class="order-2 col-span-6 sm:col-span-9 lg:col-span-10 mb-10">
#         <h4 class="text-gray-2 text-18 md:text-20 lg:text-26 col-span-10 lg:leading-28">© 2025 N + 1 Интернет-издание / Свидетельство о регистрации СМИ Эл № ФС77-67614</h4>
#       </div>
#       <div class="order-4 col-span-6 sm:col-span-9 lg:col-span-5 lg:row-span-2 mb-10 lg:mb-0">
#         <div class="text-gray-2 text-16"><p>Использование всех текстовых материалов без изменений в некоммерческих целях разрешается со ссылкой на N&nbsp;+&nbsp;1.</p>
# <p>Все аудиовизуальные произведения являются собственностью своих авторов и&nbsp;правообладателей и&nbsp;используются только в&nbsp;образовательных и&nbsp;информационных целях.</p><p>Если вы&nbsp;являетесь собственником того или иного произведения и&nbsp;не&nbsp;согласны с&nbsp;его размещением на&nbsp;нашем сайте, пожалуйста, напишите на&nbsp;<a href="/cdn-cgi/l/email-protection#1a74765a746a766f692b34686f"><span class="__cf_email__" data-cfemail="1d73715d736d71686e2c336f68">[email&#160;protected]</span></a></p>
# <p>Сайт может содержать контент, не предназначенный для лиц младше 18 лет.</p>
# <p>Связь с редакцией: <a href="/cdn-cgi/l/email-protection#a3cacdc5cce3cdd3cfd6d0928dd1d6"><span class="__cf_email__" data-cfemail="40292e262f002e302c3533716e3235">[email&#160;protected]</span></a></p></div>
#       </div>
#       <div class="order-5 col-span-6 sm:col-span-9 sm:col-start-4 lg:col-span-5 text-gray-2 text-16 leading-none flex flex-col">
#
#
#
#
#
#
#
#
#         <a class="underline transition-colors duration-75 hover:text-main inline-block col-span-6 sm:col-span-5 mb-5 font-spectral italic"
#            href="/personal-data-policy">Политика
#           обработки
#           персональных данных пользователей сайта
#         </a>
#
#       </div>
#       <div class="order-3 sm:col-span-9 lg:col-span-5 sm:order-3 lg:order-6 mt-auto col-span-6 mb-10 lg:mb-0">
#         <ul class="flex gap-3 text-gray-2">
#           <li>
#             <a class="hover:text-main" href="https://t.me/nplusone" target="_blank">
#               <svg class="w-12 h-12">
#                 <use xlink:href="#n1_tg"></use>
#               </svg>
#             </a>
#           </li>
#           <li>
#             <a class="hover:text-main" href="https://vk.com/nplusone" target="_blank">
#               <svg class="w-12 h-12">
#                 <use xlink:href="#n1_vk"></use>
#               </svg>
#             </a>
#           </li>
#           <li>
#             <a class="hover:text-main" href="https://ok.ru/nplus1" target="_blank">
#               <svg class="w-12 h-12">
#                 <use xlink:href="#n1_ok"></use>
#               </svg>
#             </a>
#           </li>
#           <li class="w-12">
#             <a class="hover:text-main" href="https://twitter.com/nplusodin" target="_blank">
#               <svg class="w-12 h-12">
#                 <use xlink:href="#n1_tw"></use>
#               </svg>
#             </a>
#           </li>
#         </ul>
#       </div>
#     </div>
#   </div>
#
# </footer>
# </div>
#
#
# <svg id="n1_star" class="stroke-current" style="display:block;width:0;height:0" xmlns="http://www.w3.org/2000/svg"
#      width="16" height="16"
#      viewBox="3 3 16 16" fill="none">
#   <path d="M11 5V17"/>
#   <path d="M6.75781 6.75781L15.2431 15.2431"/>
#   <path d="M17 11L5 11"/>
#   <path d="M15.2422 6.75781L6.75691 15.2431"/>
# </svg>
# <svg id="n1_person" class="stroke-current" style="display:block;width:0;height:0" xmlns="http://www.w3.org/2000/svg"
#      viewBox="0 0 50 50" fill="none">
#   <circle cx="25" cy="25" r="24.5"/>
#   <path d="M30.1897 30.3212C28.9483 29.9852 27.5345 29.7164 27.5345 28.5067C27.5345 27.8347 27.5 27.0618 28.2931 26.625C31.0172 25.0457 32.5 22.3911 32.1552 18.2581C31.8103 14.0578 29.2586 11 24.9828 11C20.7069 11 18.1552 14.0578 17.8103 18.2581C17.4655 22.3911 18.9138 25.0457 21.6724 26.625C22.4655 27.0618 22.431 27.8347 22.431 28.5067C22.431 29.7164 21.0172 29.9516 19.8103 30.3212C17.3966 30.9933 12.5 31.9005 12.5 36C16.431 36 33.569 36 37.5 36C37.4655 31.9005 32.6034 30.9933 30.1897 30.3212Z"
#         stroke-miterlimit="10"/>
# </svg>
# <svg id="n1_tg" style="display:block;width:0;height:0" xmlns="http://www.w3.org/2000/svg" viewBox="0 0 50 50"
#      fill="none">
#   <path d="M16.3181 21.32H19.4961V30H20.7141V21.32H23.8921V20.2H16.3181V21.32ZM28.6969 30.084C30.3769 30.084 31.4269 29.286 31.8749 28.572L31.9589 30H33.0089V24.694H28.8789V25.814H31.8189V26.15C31.8189 27.886 30.5169 28.964 28.7109 28.964C26.6809 28.964 25.3369 27.368 25.3369 25.1C25.3369 22.832 26.6809 21.236 28.7389 21.236C30.2229 21.236 31.2729 22.034 31.6089 23.392H32.9109C32.5749 21.376 30.9369 20.116 28.7669 20.116C25.9249 20.116 24.0909 22.132 24.0909 25.1C24.0909 28.068 25.9809 30.084 28.6969 30.084Z"
#         class="fill-current"/>
#   <circle cx="25" cy="25" r="24.5" class="stroke-current"/>
# </svg>
# <svg id="n1_vk" style="display:block;width:0;height:0" viewBox="0 0 50 50" fill="none"
#      xmlns="http://www.w3.org/2000/svg">
#   <path d="M19.8015 30H21.2715L24.7995 20.2H23.5395L20.5575 28.558L17.5615 20.2H16.2735L19.8015 30ZM25.8768 30H27.0948V27.452L29.0408 25.254L32.3448 30H33.8008L29.9368 24.33L33.5208 20.2H32.0368L27.0948 25.758V20.2H25.8768V30Z"
#         class="fill-current"></path>
#   <circle cx="25" cy="25" r="24.5" class="stroke-current"></circle>
# </svg>
# <svg id="n1_ok" style="display:block;width:0;height:0" viewBox="0 0 50 50" fill="none"
#      xmlns="http://www.w3.org/2000/svg">
#   <path d="M25.2125 25.1C25.2125 22.216 23.2945 20.116 20.5365 20.116C17.7785 20.116 15.8605 22.216 15.8605 25.1C15.8605 27.984 17.7785 30.084 20.5365 30.084C23.2945 30.084 25.2125 27.984 25.2125 25.1ZM17.1065 25.1C17.1065 22.846 18.4925 21.236 20.5365 21.236C22.5805 21.236 23.9665 22.846 23.9665 25.1C23.9665 27.354 22.5805 28.964 20.5365 28.964C18.4925 28.964 17.1065 27.354 17.1065 25.1ZM26.7518 30H27.9698V27.452L29.9158 25.254L33.2198 30H34.6758L30.8118 24.33L34.3958 20.2H32.9118L27.9698 25.758V20.2H26.7518V30Z"
#         class="fill-current"></path>
#   <circle cx="25" cy="25" r="24.5" class="stroke-current"></circle>
# </svg>
# <svg id="n1_tw" style="display:block;width:0;height:0" viewBox="0 0 50 50" fill="none"
#      xmlns="http://www.w3.org/2000/svg">
#   <path d="M14.4792 21.32H17.6572V30H18.8752V21.32H22.0532V20.2H14.4792V21.32ZM25.332 30H26.788L29.014 22.23L31.254 30H32.71L35.58 20.2H34.32L32.01 28.432L29.686 20.2H28.454L26.046 28.432L23.75 20.2H22.476L25.332 30Z"
#         class="fill-current"></path>
#   <circle cx="25" cy="25" r="24.5" class="stroke-current"></circle>
# </svg>
# <svg id="n1_infinity" style="display:block;width:0;height:0" xmlns="http://www.w3.org/2000/svg"
#      xmlns:xlink="http://www.w3.org/1999/xlink" width="64px" height="64px" viewBox="0 0 100 100"
#      preserveAspectRatio="xMidYMid">
#   <path fill="none" stroke="#ffffff" stroke-width="5" stroke-dasharray="146.25568908691406 110.33323913574219"
#         d="M24.3 30C11.4 30 5 43.3 5 50s6.4 20 19.3 20c19.3 0 32.1-40 51.4-40 C88.6 30 95 43.3 95 50s-6.4 20-19.3 20C56.4 70 43.6 30 24.3 30z"
#         stroke-linecap="round" style="transform:scale(0.8);transform-origin:50px 50px">
#     <animate attributeName="stroke-dashoffset" repeatCount="indefinite" dur="1.3157894736842106s" keyTimes="0;1"
#              values="0;256.58892822265625"></animate>
#   </path>
# </svg>
# <svg id="n1_cross" style="display:block;width:0;height:0" xmlns="http://www.w3.org/2000/svg" viewBox="0 0 14 14"
#      fill="none">
#   <path d="M1.00146 1L13.0015 13" stroke="#F9F9F9"/>
#   <path d="M13 1L1 13" stroke="#F9F9F9"/>
# </svg>
# <svg id="n1_link_arrow" style="display:block;width:0;height:0" viewBox="0 0 11 11" xmlns="http://www.w3.org/2000/svg">
#   <path d="M10.0738 5.87L5.08775 0.901999L4.15175 1.838L7.51775 5.204H0.19175V6.536H7.51775L4.15175 9.902L5.08775 10.838L10.0738 5.87Z"
#         fill="currentColor"></path>
# </svg>
# <svg id="n1_big_star" style="display:block;width:0;height:0;" xmlns="http://www.w3.org/2000/svg" viewBox="0 0 61 61">
#   <path class="fill-current" fill-rule="evenodd" clip-rule="evenodd"
#         d="M3 29.7729H29.0656L10.6345 11.3418L11.3416 10.6347L29.7728 29.0658V3H30.7728V29.0658L49.2039 10.6347L49.911 11.3418L31.4799 29.7729H57.5455V30.7729H31.4799L49.9111 49.2042L49.204 49.9113L30.7728 31.4801V57.5455H29.7728V31.4801L11.3415 49.9113L10.6344 49.2042L29.0656 30.7729H3V29.7729Z"/>
#   <path class="fill-current"
#         d="M29.0656 29.7729V32.2729H35.1012L30.8334 28.0052L29.0656 29.7729ZM3 29.7729V27.2729H0.5V29.7729H3ZM10.6345 11.3418L8.86676 9.57407L7.099 11.3418L8.86676 13.1096L10.6345 11.3418ZM11.3416 10.6347L13.1094 8.86696L11.3416 7.09919L9.57387 8.86696L11.3416 10.6347ZM29.7728 29.0658L28.005 30.8336L32.2728 35.1014V29.0658H29.7728ZM29.7728 3V0.5H27.2728V3H29.7728ZM30.7728 3H33.2728V0.5H30.7728V3ZM30.7728 29.0658H28.2728V35.1014L32.5405 30.8336L30.7728 29.0658ZM49.2039 10.6347L50.9716 8.86696L49.2039 7.09919L47.4361 8.86696L49.2039 10.6347ZM49.911 11.3418L51.6787 13.1096L53.4465 11.3418L51.6787 9.57407L49.911 11.3418ZM31.4799 29.7729L29.7121 28.0052L25.4443 32.2729H31.4799V29.7729ZM57.5455 29.7729H60.0455V27.2729H57.5455V29.7729ZM57.5455 30.7729V33.2729H60.0455V30.7729H57.5455ZM31.4799 30.7729V28.2729H25.4443L29.7121 32.5407L31.4799 30.7729ZM49.9111 49.2042L51.6789 50.972L53.4466 49.2042L51.6789 47.4364L49.9111 49.2042ZM49.204 49.9113L47.4362 51.6791L49.204 53.4468L50.9718 51.6791L49.204 49.9113ZM30.7728 31.4801L32.5405 29.7123L28.2728 25.4445V31.4801H30.7728ZM30.7728 57.5455V60.0455H33.2728V57.5455H30.7728ZM29.7728 57.5455H27.2728V60.0455H29.7728V57.5455ZM29.7728 31.4801H32.2728V25.4445L28.005 29.7123L29.7728 31.4801ZM11.3415 49.9113L9.57374 51.6791L11.3415 53.4468L13.1093 51.6791L11.3415 49.9113ZM10.6344 49.2042L8.86664 47.4364L7.09887 49.2042L8.86664 50.972L10.6344 49.2042ZM29.0656 30.7729L30.8334 32.5407L35.1012 28.2729H29.0656V30.7729ZM3 30.7729H0.5V33.2729H3V30.7729ZM29.0656 27.2729H3V32.2729H29.0656V27.2729ZM8.86676 13.1096L27.2979 31.5407L30.8334 28.0052L12.4023 9.57407L8.86676 13.1096ZM9.57387 8.86696L8.86676 9.57407L12.4023 13.1096L13.1094 12.4025L9.57387 8.86696ZM31.5405 27.2981L13.1094 8.86696L9.57387 12.4025L28.005 30.8336L31.5405 27.2981ZM27.2728 3V29.0658H32.2728V3H27.2728ZM30.7728 0.5H29.7728V5.5H30.7728V0.5ZM33.2728 29.0658V3H28.2728V29.0658H33.2728ZM32.5405 30.8336L50.9716 12.4025L47.4361 8.86696L29.005 27.2981L32.5405 30.8336ZM47.4361 12.4025L48.1432 13.1096L51.6787 9.57407L50.9716 8.86696L47.4361 12.4025ZM48.1432 9.57407L29.7121 28.0052L33.2476 31.5407L51.6787 13.1096L48.1432 9.57407ZM57.5455 27.2729H31.4799V32.2729H57.5455V27.2729ZM60.0455 30.7729V29.7729H55.0455V30.7729H60.0455ZM31.4799 33.2729H57.5455V28.2729H31.4799V33.2729ZM51.6789 47.4364L33.2476 29.0052L29.7121 32.5407L48.1433 50.972L51.6789 47.4364ZM50.9718 51.6791L51.6789 50.972L48.1433 47.4364L47.4362 48.1435L50.9718 51.6791ZM29.005 33.2478L47.4362 51.6791L50.9718 48.1435L32.5405 29.7123L29.005 33.2478ZM33.2728 57.5455V31.4801H28.2728V57.5455H33.2728ZM29.7728 60.0455H30.7728V55.0455H29.7728V60.0455ZM27.2728 31.4801V57.5455H32.2728V31.4801H27.2728ZM28.005 29.7123L9.57374 48.1435L13.1093 51.6791L31.5405 33.2478L28.005 29.7123ZM13.1093 48.1435L12.4022 47.4364L8.86664 50.972L9.57374 51.6791L13.1093 48.1435ZM12.4022 50.972L30.8334 32.5407L27.2979 29.0052L8.86664 47.4364L12.4022 50.972ZM3 33.2729H29.0656V28.2729H3V33.2729ZM0.5 29.7729V30.7729H5.5V29.7729H0.5Z"/>
# </svg>
# <svg id="n1_circle_arrow" style="display:block;width:0;height:0" class="stroke-current"
#      xmlns="http://www.w3.org/2000/svg" viewBox="0 0 30 30" fill="none">
#   <rect x="29.5" y="29.5" width="29" height="29" rx="14.5" transform="rotate(-180 29.5 29.5)"/>
#   <path d="M9.33985 14.7014L14.6198 19.9414L15.2598 19.3014L11.1198 15.1614L20.3398 15.1614L20.3398 14.2214L11.1198 14.2214L15.2598 10.0814L14.6198 9.44141L9.33985 14.7014Z"/>
# </svg>
# <svg id="n1_circle_arrow_solid" style="display:block;width:0;height:0" xmlns="http://www.w3.org/2000/svg"
#      viewBox="0 0 30 30" fill="none">
#   <mask id="path-1-inside-1_2694_77554">
#     <path fill-rule="evenodd" clip-rule="evenodd"
#           d="M15 0C6.71573 0 0 6.71573 0 15C0 23.2843 6.71573 30 15 30C23.2843 30 30 23.2843 30 15C30 6.71573 23.2843 0 15 0ZM15.3792 10.0601L20.6592 15.3001L15.3792 20.5601L14.7392 19.9201L18.8792 15.7801H9.65918V14.8401H18.8792L14.7392 10.7001L15.3792 10.0601Z"/>
#   </mask>
#   <path fill-rule="evenodd" clip-rule="evenodd"
#         d="M15 0C6.71573 0 0 6.71573 0 15C0 23.2843 6.71573 30 15 30C23.2843 30 30 23.2843 30 15C30 6.71573 23.2843 0 15 0ZM15.3792 10.0601L20.6592 15.3001L15.3792 20.5601L14.7392 19.9201L18.8792 15.7801H9.65918V14.8401H18.8792L14.7392 10.7001L15.3792 10.0601Z"
#         fill="#fff"/>
#   <path d="M20.6592 15.3001L21.3649 16.0085L22.0774 15.2987L21.3636 14.5903L20.6592 15.3001ZM15.3792 10.0601L16.0836 9.35027L15.3765 8.64853L14.6721 9.35295L15.3792 10.0601ZM15.3792 20.5601L14.6721 21.2672L15.3778 21.9729L16.0849 21.2685L15.3792 20.5601ZM14.7392 19.9201L14.0321 19.213L13.325 19.9201L14.0321 20.6272L14.7392 19.9201ZM18.8792 15.7801L19.5863 16.4872L21.2934 14.7801H18.8792V15.7801ZM9.65918 15.7801H8.65918V16.7801H9.65918V15.7801ZM9.65918 14.8401V13.8401H8.65918V14.8401H9.65918ZM18.8792 14.8401V15.8401H21.2934L19.5863 14.133L18.8792 14.8401ZM14.7392 10.7001L14.0321 9.99295L13.325 10.7001L14.0321 11.4072L14.7392 10.7001ZM1 15C1 7.26801 7.26801 1 15 1V-1C6.16344 -1 -1 6.16344 -1 15H1ZM15 29C7.26801 29 1 22.732 1 15H-1C-1 23.8366 6.16344 31 15 31V29ZM29 15C29 22.732 22.732 29 15 29V31C23.8366 31 31 23.8366 31 15H29ZM15 1C22.732 1 29 7.26801 29 15H31C31 6.16344 23.8366 -1 15 -1V1ZM21.3636 14.5903L16.0836 9.35027L14.6748 10.7698L19.9548 16.0098L21.3636 14.5903ZM16.0849 21.2685L21.3649 16.0085L19.9534 14.5916L14.6734 19.8516L16.0849 21.2685ZM14.0321 20.6272L14.6721 21.2672L16.0863 19.853L15.4463 19.213L14.0321 20.6272ZM18.1721 15.073L14.0321 19.213L15.4463 20.6272L19.5863 16.4872L18.1721 15.073ZM9.65918 16.7801H18.8792V14.7801H9.65918V16.7801ZM8.65918 14.8401V15.7801H10.6592V14.8401H8.65918ZM18.8792 13.8401H9.65918V15.8401H18.8792V13.8401ZM14.0321 11.4072L18.1721 15.5472L19.5863 14.133L15.4463 9.99295L14.0321 11.4072ZM14.6721 9.35295L14.0321 9.99295L15.4463 11.4072L16.0863 10.7672L14.6721 9.35295Z"
#         fill="#fff" mask="url(#path-1-inside-1_2694_77554)"/>
# </svg>
# <svg id="n1_play" style="display:block;width:0;height:0;" xmlns="http://www.w3.org/2000/svg" viewBox="0 0 50 50"
#      fill="none">
#   <circle cx="25" cy="25" r="24.5" class="stroke-current"/>
#   <path d="M18 35V15L36 25L18 35Z" class="stroke-current"/>
# </svg>
# <svg id="n1_pupa" style="display:block;width:0;height:0;" xmlns="http://www.w3.org/2000/svg" viewBox="0 0 24 23"
#      fill="none">
#   <path fill-rule="evenodd" clip-rule="evenodd"
#         d="M17 8.80329C17 13.0922 13.4392 16.6066 9 16.6066C4.56077 16.6066 1 13.0922 1 8.80329C1 4.51437 4.56077 1 9 1C13.4392 1 17 4.51437 17 8.80329ZM14.9967 15.3678C13.4049 16.7601 11.3035 17.6066 9 17.6066C4.02944 17.6066 0 13.6652 0 8.80329C0 3.94137 4.02944 0 9 0C13.9706 0 18 3.94137 18 8.80329C18 11.0562 17.1348 13.1114 15.7118 14.6684L23.3531 22.1427C23.5505 22.3358 23.554 22.6524 23.3609 22.8498C23.1678 23.0472 22.8513 23.0507 22.6539 22.8576L14.9967 15.3678Z"
#         fill="#32363A"/>
# </svg>
# <svg id="n1_burger" style="display:block;width:0;height:0;" viewBox="0 0 30 30" fill="none"
#      xmlns="http://www.w3.org/2000/svg">
#   <line y1="6.5" x2="30" y2="6.5" stroke="#32363A"/>
#   <line y1="23.5" x2="30" y2="23.5" stroke="#32363A"/>
#   <line y1="15" x2="30" y2="15" stroke="#32363A"/>
# </svg>
# <svg id="n1_cross_menu" style="display:block;width:0;height:0;" xmlns="http://www.w3.org/2000/svg" viewBox="0 0 30 30"
#      fill="none">
#   <path d="M4 4L26 26" stroke="#32363A"/>
#   <path d="M26 4L4 26" stroke="#32363A"/>
# </svg>
# <svg id="n1_check" style="display:block;width:0;height:0;fill:currentColor" xmlns="http://www.w3.org/2000/svg"
#      version="1.1" viewBox="0 0 752 752">
#   <path d="m183.6 357.87-22.184 22.168v0.003907c-3.2969 3.293-3.2969 8.6367 0 11.934l133.29 133.28v0.003907c3.7305 3.7266 8.7891 5.8242 14.066 5.8242 5.2734 0 10.332-2.0977 14.062-5.8242l267.76-267.76c1.582-1.582 2.4727-3.7305 2.4727-5.9688 0-2.2383-0.89062-4.3867-2.4727-5.9688l-22.156-22.168c-1.582-1.5898-3.7344-2.4805-5.9727-2.4805-2.2422 0-4.3945 0.89062-5.9766 2.4805l-244.31 244.3c-1.8828 1.8789-4.9336 1.8789-6.8164 0l-109.84-109.83c-3.293-3.2852-8.625-3.2852-11.918 0z"/>
# </svg>
# <svg id="n1_specials_star"
#   style="display:block;width:0;height:0;fill:none;stroke:white"
#   xmlns="http://www.w3.org/2000/svg"
#   version="1.1" viewBox="0 0 16 16">
#   <path d="M7.99982 2.18188L9.79764 5.77236L13.818 6.35166L10.9089 9.14489L11.5955 13.091L7.99982 11.2269L4.40419 13.091L5.09073 9.14489L2.18164 6.35166L6.202 5.77236L7.99982 2.18188Z" stroke-linecap="round"/>
# </svg>
#
# <script data-cfasync="false" src="/cdn-cgi/scripts/5c5dd728/cloudflare-static/email-decode.min.js"></script><script src="/front-build/js/app.js?id=dd5e25d7814af92b9161a324a2c82337"></script>
#
#
#
#
#   <!-- Yandex.Metrika counter 2-->
# <script type="text/javascript" >
# (function(m,e,t,r,i,k,a){m[i]=m[i]||function(){(m[i].a=m[i].a||[]).push(arguments)};
# 	m[i].l=1*new Date();k=e.createElement(t),a=e.getElementsByTagName(t)[0],k.async=1,k.src=r,a.parentNode.insertBefore(k,a)})
# (window, document, "script", "https://mc.yandex.ru/metrika/tag.js", "ym");
#
# ym(88946384, "init", {
# 	clickmap:true,
# 	trackLinks:true,
# 	accurateTrackBounce:true,
# 	webvisor:true
# });
#
#
# ym(29654565, "init", {
# 	clickmap:true,
# 	trackLinks:true,
# 	accurateTrackBounce:true,
# 	webvisor:true,
# 	trackHash:true,
# 	ecommerce:"dataLayer"
# });
# </script>
# <noscript>
#   <div>
#     <img src="https://mc.yandex.ru/watch/88946384" style="position:absolute; left:-9999px;" alt="" />
#     <img src="https://mc.yandex.ru/watch/29654565" style="position:absolute; left:-9999px;" alt="" />
#   </div>
# </noscript>
# <!-- /Yandex.Metrika counter -->
#
# <script async src="https://www.googletagmanager.com/gtag/js?id=UA-61773772-1"></script>
# <script>
# window.dataLayer = window.dataLayer || [];
# function gtag(){dataLayer.push(arguments);}
# gtag('js', new Date());
# gtag('config', 'UA-61773772-1');
# </script>
#
#
#   <script>window.yaContextCb = window.yaContextCb || []</script>
#   <script src="https://yandex.ru/ads/system/context.js" async></script>
#
#
#
#
# <script>
# if ('serviceWorker' in navigator) {
# 	window.addEventListener('load', () => {
# 		navigator.serviceWorker.register('/front-service-worker.js').then(reg => {
# 			// sometime later…
# 			reg.update()
# 		})
# 	})
# }
# </script>
#
#
#
#
# </body>
# </html>

# %%
from bs4 import BeautifulSoup

# %%
page = BeautifulSoup(response.text, 'html.parser') # Создаём объект BeautifulSoup, указывая html-парсер
print(page.title) # Получаем тег title, отображающийся на вкладке браузера
print(page.title.text) # Выводим текст из полученного тега, который содержится в атрибуте text
# Out:
# <title>Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей</title>
# Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей

# %%
# Применяем метод find() к объекту и выводим результат на экран
print(page.find('h1').text)
# Out:
#             Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей

# %%
# Выводим содержимое атрибута text тега div класса n1_material text-18
print(page.find('div', class_='n1_material text-18').text)
# Out:
# Премия Шведского национального банка по экономическим наукам памяти Альфреда Нобеля за 2021 год присуждена Дэвиду Карду (David Card) за его вклад в эмпирические исследования экономики рынка труда, а также Джошуа Энгристу (Joshua Angrist) и Гвидо Имбенсу (Guido Imbens) за их вклад в методологию анализа причинно-следственных связей. Прямая трансляция церемонии объявления лауреатов шла на официальном сайте Нобелевской премии.

# %%
# Выводим на экран содержимое атрибута text тега a с классом "relative"
print(page.find('a', class_= "relative").text)
# Out:
# 11.10.21

# %%
url = 'https://en.wikipedia.org/wiki/List_of_programming_languages' # Задаём адрес ресурса
response = requests.get(url) # Делаем GET-запрос к ресурсу
page = BeautifulSoup(response.text, 'html.parser') # Создаём объект BeautifulSoup
print(page.find('a')) # Ищем ссылку по тегу <a> и выводим её на экран
# Out:
# <a class="mw-jump-link" href="#bodyContent">Jump to content</a>

# %%
links = page.find_all('a') # Ищем все ссылки на странице и сохраняем в переменной links в виде списка
print(len(links)) # Выводим количество найденных ссылок
# Out:
# 966

# %%
print([link.text for link in links[500:510]]) # Выводим ссылки с 500 по 509 включительно
# Out:
# ['MAD', 'MAD/I', 'Magik', 'Magma', 'Maple', 'MAPPER', 'MARK-IV', 'Mary', 'MATLAB', 'MASM Microsoft Assembly x86']

# %%
import requests # Импортируем модуль requests
token = 'fb78c49ffb78c49ffb78c49f29f85b4f33ffb78fb78c49f9c4a8467da555d787ddec9c1' # Указываем свой сервисный токен
url = 'https://api.vk.com/method/users.get' # Указываем адрес страницы к которой делаем запрос
params = {'user_id': 1, 'v': 5.95, 'fields': 'sex,bdate', 'access_token': token, 'lang': 'ru'} # Перечисляем параметры нашего запроса в словаре params
response = requests.get(url, params=params) # Отправляем запрос
print(response.text) # Выводим текст ответа на экран
# Out:
# {"response":[{"id":1,"bdate":"10.10.1984","sex":2,"first_name":"Павел","last_name":"Дуров","can_access_closed":true,"is_closed":false}]}

# %%
from pprint import pprint # Импортируем функцию pprint()
pprint(response.json()) # Выводим содержимое словаря, содержащего ответ, на экра
# Out:
# {'response': [{'bdate': '10.10.1984',
#                'can_access_closed': True,
#                'first_name': 'Павел',
#                'id': 1,
#                'is_closed': False,
#                'last_name': 'Дуров',
#                'sex': 2}]}

# %%
user = response.json()['response'][0] # Извлекаем из словаря по ключу response информацию о первом пользователе
print(user['bdate']) # Выводим дату рождения первого пользователя на экран
# Out:
# 10.10.1984

# %%
ids = ",".join(map(str, range(1, 4))) # Формируем строку, содержащую информацию о поле id первых трёх пользователей
params = {'user_ids': ids, 'v': 5.95, 'fields': 'bdate', 'access_token': token, 'lang': 'ru'} # Формируем строку параметров
pprint(requests.get(url, params=params).json()) # Посылаем запрос, полученный ответ в формате JSON-строки преобразуем в словарь и выводим на экран его содержимое, используя функцию pprint()
# Out:
# {'response': [{'bdate': '10.10.1984',
#                'can_access_closed': True,
#                'first_name': 'Павел',
#                'id': 1,
#                'is_closed': False,
#                'last_name': 'Дуров'},
#               {'bdate': '14.2',
#                'can_access_closed': False,
#                'first_name': 'Александра',
#                'id': 2,
#                'is_closed': True,
#                'last_name': 'Владимирова'},
#               {'can_access_closed': True,
#                'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 3,
#                'is_closed': False,
#                'last_name': ''}]}

# %%
ids = ",".join(map(str, range(1, 501))) # Формируем строку, содержащую информацию о поле id первых трёх пользователей
params = {'user_ids': ids, 'v': 5.95, 'fields': 'sex', 'access_token': token, 'lang': 'ru'} # Формируем строку параметров
response = (requests.get(url, params=params)) # Посылаем запрос, полученный ответ в формате JSON-строки преобразуем в словарь и выводим на экран его содержимое, используя функцию pprint()

# %%
users = response.json()['response']
sex = {0 : 0,
      1 : 0,
      2 : 0}
for user in users:
    if str(user['first_name']) == "DELETED":
        continue
    sex[user['sex']] +=1
print(sex[1]/(sex[2]+sex[1]))
# Out:
# 0.48860759493670886

# %%
import requests # Импортируем модуль requests
token = 'fb78c49ffb78c49ffb78c49f29f85b4f33ffb78fb78c49f9c4a8467da555d787ddec9c1' # Указываем свой сервисный токен
url = 'https://api.vk.com/method/groups.getMembers' # Указываем адрес обращения
params = {'group_id': 'vk', 'v': 5.95, 'access_token': token} # Формируем строку параметров
response = requests.get(url, params = params) # Посылаем запрос
data = response.json() # Ответ сохраняем в переменной data в формате словаря
print(data) # Выводим содержимое переменной data на экран (отображён фрагмент)
# Out:
# {'response': {'count': 20296766, 'items': [5, 6, 14, 19, 34, 47, 54, 79, 88, 102, 106, 163, 166, 177, 198, 212, 219, 243, 259, 279, 296, 302, 344, 345, 353, 403, 404, 421, 431, 433, 450, 467, 485, 510, 513, 550, 619, 628, 640, 670, 690, 696, 702, 721, 741, 804, 809, 832, 834, 847, 900, 905, 907, 914, 921, 943, 952, 958, 966, 976, 997, 1000, 1011, 1018, 1023, 1033, 1039, 1058, 1059, 1091, 1097, 1127, 1128, 1131, 1139, 1140, 1159, 1174, 1179, 1181, 1185, 1188, 1207, 1213, 1245, 1270, 1273, 1301, 1322, 1333, 1334, 1351, 1381, 1386, 1388, 1406, 1411, 1418, 1432, 1470, 1490, 1494, 1498, 1503, 1529, 1531, 1550, 1568, 1570, 1575, 1586, 1590, 1593, 1598, 1610, 1615, 1632, 1634, 1635, 1650, 1665, 1674, 1679, 1690, 1697, 1698, 1699, 1700, 1721, 1740, 1745, 1754, 1814, 1818, 1820, 1822, 1829, 1834, 1839, 1840, 1843, 1852, 1858, 1863, 1869, 1887, 1889, 1917, 1925, 1936, 1941, 1943, 1946, 1947, 1955, 1969, 1989, 2019, 2022, 2028, 2030, 2042, 2050, 2051, 2052, 2059, 2069, 2077, 2103, 2136, 2150, 2152, 2195, 2201, 2222, 2230, 2236, 2273, 2281, 2296, 2298, 2306, 2375, 2376, 2389, 2395, 2403, 2412, 2413, 2436, 2444, 2456, 2466, 2470, 2484, 2498, 2513, 2515, 2523, 2534, 2538, 2539, 2576, 2592, 2593, 2601, 2617, 2622, 2629, 2644, 2654, 2663, 2676, 2692, 2703, 2706, 2745, 2755, 2767, 2787, 2788, 2797, 2813, 2827, 2835, 2858, 2860, 2894, 2908, 2909, 2919, 2922, 2932, 2943, 2953, 2962, 2965, 2969, 2982, 3001, 3006, 3041, 3130, 3135, 3139, 3153, 3162, 3172, 3186, 3196, 3203, 3231, 3250, 3254, 3290, 3316, 3321, 3328, 3331, 3332, 3357, 3364, 3372, 3373, 3383, 3384, 3388, 3402, 3420, 3422, 3427, 3431, 3436, 3438, 3450, 3451, 3458, 3472, 3483, 3486, 3491, 3492, 3520, 3545, 
url = 'https://api.vk.com/method/wall.get' # Указываем адрес страницы, к которой делаем запрос
params = {'domain': 'vk', 'filter': 'owner', 'count': 1000, 'offset': 0, 'access_token': token, 'v': 5.95} 
response = requests.get(url, params = params) 
pprint(response.json())
# Out:
# {'response': {'count': 845,
#               'items': [{'attachments': [{'photo': {'access_key': 'b9d98a00ced8ca402b',
#                                                     'album_id': -7,
#                                                     'date': 1750674662,
#                                                     'id': 457364376,
#                                                     'orig_photo': {'height': 1500,
#                                                                    'type': 'base',
#                                                                    'url': 'https://sun66-1.userapi.com/s/v1/ig2/sV_3_Z5PFY6cWKrxN8A_KMEjD_40GRDokAuur3Yk5pqW5s4NOSJJ0xvowLFrOV54nSpY6uAdCfA4IA8KYwNQi4Pv.jpg?quality=95&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1500x1500&from=bu',
#                                                                    'width': 1500},
#                                                     'owner_id': -22822305,
#                                                     'sizes': [{'height': 72,
#                                                                'type': 's',
#                                                                'url': 'https://sun66-1.userapi.com/s/v1/ig2/sV_3_Z5PFY6cWKrxN8A_KMEjD_40GRDokAuur3Yk5pqW5s4NOSJJ0xvowLFrOV54nSpY6uAdCfA4IA8KYwNQi4Pv.jpg?quality=95&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1500x1500&from=bu&cs=72x0',
#                                                                'width': 72},
#                                                               {'height': 160,
#                                                                'type': 'm',
#                                                                'url': 'https://sun66-1.userapi.com/s/v1/ig2/sV_3_Z5PFY6cWKrxN8A_KMEjD_40GRDokAuur3Yk5pqW5s4NOSJJ0xvowLFrOV54nSpY6uAdCfA4IA8KYwNQi4Pv.jpg?quality=95&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1500x1500&from=bu&cs=160x0',
#                                                                'width': 160},
#                                                               {'height': 640,
#                                                                'type': 'x',
#                                                                'url': 'https://sun66-1.userapi.com/s/v1/ig2/sV_3_Z5PFY6cWKrxN8A_KMEjD_40GRDokAuur3Yk5pqW5s4NOSJJ0xvowLFrOV54nSpY6uAdCfA4IA8KYwNQi4Pv.jpg?quality=95&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1500x1500&from=bu&cs=640x0',
#                                                                'width': 640},
#                                                               {'height': 1080,
#                                                                'type': 'y',
#                                                                'url': 'https://sun66-1.userapi.com/s/v1/ig2/sV_3_Z5PFY6cWKrxN8A_KMEjD_40GRDokAuur3Yk5pqW5s4NOSJJ0xvowLFrOV54nSpY6uAdCfA4IA8KYwNQi4Pv.jpg?quality=95&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1500x1500&from=bu&cs=1080x0',
#                                                                'width': 1080},
#                                                               {'height': 1280,
#                                                                'type': 'z',
#                                                                'url': 'https://sun66-1.userapi.com/s/v1/ig2/sV_3_Z5PFY6cWKrxN8A_KMEjD_40GRDokAuur3Yk5pqW5s4NOSJJ0xvowLFrOV54nSpY6uAdCfA4IA8KYwNQi4Pv.jpg?quality=95&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1500x1500&from=bu&cs=1280x0',
#                                                                'width': 1280},
#                                                               {'height': 1500,
#                                                                'type': 'w',
#                                                                'url': 'https://sun66-1.userapi.com/s/v1/ig2/sV_3_Z5PFY6cWKrxN8A_KMEjD_40GRDokAuur3Yk5pqW5s4NOSJJ0xvowLFrOV54nSpY6uAdCfA4IA8KYwNQi4Pv.jpg?quality=95&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1500x1500&from=bu&cs=1500x0',
#                                                                'width': 1500},
#                                                               {'height': 108,
#                                                                'type': 'o',
#                                                                'url': 'https://sun66-1.userapi.com/s/v1/ig2/sV_3_Z5PFY6cWKrxN8A_KMEjD_40GRDokAuur3Yk5pqW5s4NOSJJ0xvowLFrOV54nSpY6uAdCfA4IA8KYwNQi4Pv.jpg?quality=95&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1500x1500&from=bu&cs=108x0',
#                                                                'width': 108},
#                                                               {'height': 240,
#                                                                'type': 'p',
#                                                                'url': 'https://sun66-1.userapi.com/s/v1/ig2/sV_3_Z5PFY6cWKrxN8A_KMEjD_40GRDokAuur3Yk5pqW5s4NOSJJ0xvowLFrOV54nSpY6uAdCfA4IA8KYwNQi4Pv.jpg?quality=95&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1500x1500&from=bu&cs=240x0',
#                                                                'width': 240},
#                                                               {'height': 360,
#                                                                'type': 'q',
#                                                                'url': 'https://sun66-1.userapi.com/s/v1/ig2/sV_3_Z5PFY6cWKrxN8A_KMEjD_40GRDokAuur3Yk5pqW5s4NOSJJ0xvowLFrOV54nSpY6uAdCfA4IA8KYwNQi4Pv.jpg?quality=95&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1500x1500&from=bu&cs=360x0',
#                                                                'width': 360},
#                                                               {'height': 540,
#                                                                'type': 'r',
#                                                                'url': 'https://sun66-1.userapi.com/s/v1/ig2/sV_3_Z5PFY6cWKrxN8A_KMEjD_40GRDokAuur3Yk5pqW5s4NOSJJ0xvowLFrOV54nSpY6uAdCfA4IA8KYwNQi4Pv.jpg?quality=95&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1500x1500&from=bu&cs=540x0',
#                                                                'width': 540},
#                                                               {'height': 1500,
#                                                                'type': 'base',
#                                                                'url': 'https://sun66-1.userapi.com/s/v1/ig2/sV_3_Z5PFY6cWKrxN8A_KMEjD_40GRDokAuur3Yk5pqW5s4NOSJJ0xvowLFrOV54nSpY6uAdCfA4IA8KYwNQi4Pv.jpg?quality=95&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1500x1500&from=bu',
#                                                                'width': 1500}],
#                                                     'text': '',
#                                                     'user_id': 100,
#                                                     'web_view_token': 'fd753b313312247419'},
#                                           'type': 'photo'}],
#                          'comments': {'count': 97},
#                          'date': 1750675407,
#                          'from_id': -22822305,
#                          'hash': 'KmfBJULnFiC85HSngg',
#                          'id': 1612255,
#                          'inner_type': 'wall_wallpost',
#                          'likes': {'can_like': 0,
#                                    'count': 142,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_type': 'post',
#                          'push_subscription': {'is_subscribed': False},
#                          'reposts': {'count': 16},
#                          'text': '58 миллионов человек смотрят истории '
#                                  'ВКонтакте каждый месяц\n'
#                                  '\n'
#                                  'За год просмотры историй выросли на 26%, а '
#                                  'дневная аудитория — на 14%. Истории стали '
#                                  'одним из самых быстрорастущих форматов на '
#                                  'платформе.\n'
#                                  '\n'
#                                  'Ещё несколько интересных фактов из нашего '
#                                  'исследования:\n'
#                                  '• В среднем каждый зритель смотрит 23 '
#                                  'истории в день\n'
#                                  '• Активнее всего истории публикуют в '
#                                  'выходные вечером\n'
#                                  '• Почти миллион человек в день делятся '
#                                  'историями только с друзьями',
#                          'type': 'post',
#                          'views': {'count': 42515}},
#                         {'attachments': [{'photo': {'access_key': 'fdda2374fb76a11418',
#                                                     'album_id': -7,
#                                                     'date': 1750427771,
#                                                     'id': 457364313,
#                                                     'orig_photo': {'height': 1080,
#                                                                    'type': 'base',
#                                                                    'url': 'https://sun66-1.userapi.com/s/v1/ig2/LGKJCEWtZZlI4-hABbs6eiN_NuufX6UyCdco0z2MSQYfm9x3gnZZUnPbWrHO_-BFYSRSV34_IzpdxcS8SU4L94Ak.jpg?quality=95&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu',
#                                                                    'width': 1080},
#                                                     'owner_id': -22822305,
#                                                     'sizes': [{'height': 72,
#                                                                'type': 's',
#                                                                'url': 'https://sun66-1.userapi.com/s/v1/ig2/LGKJCEWtZZlI4-hABbs6eiN_NuufX6UyCdco0z2MSQYfm9x3gnZZUnPbWrHO_-BFYSRSV34_IzpdxcS8SU4L94Ak.jpg?quality=95&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=72x0',
#                                                                'width': 72},
#                                                               {'height': 160,
#                                                                'type': 'm',
#                                                                'url': 'https://sun66-1.userapi.com/s/v1/ig2/LGKJCEWtZZlI4-hABbs6eiN_NuufX6UyCdco0z2MSQYfm9x3gnZZUnPbWrHO_-BFYSRSV34_IzpdxcS8SU4L94Ak.jpg?quality=95&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=160x0',
#                                                                'width': 160},
#                                                               {'height': 640,
#                                                                'type': 'x',
#                                                                'url': 'https://sun66-1.userapi.com/s/v1/ig2/LGKJCEWtZZlI4-hABbs6eiN_NuufX6UyCdco0z2MSQYfm9x3gnZZUnPbWrHO_-BFYSRSV34_IzpdxcS8SU4L94Ak.jpg?quality=95&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=640x0',
#                                                                'width': 640},
#                                                               {'height': 1080,
#                                                                'type': 'y',
#                                                                'url': 'https://sun66-1.userapi.com/s/v1/ig2/LGKJCEWtZZlI4-hABbs6eiN_NuufX6UyCdco0z2MSQYfm9x3gnZZUnPbWrHO_-BFYSRSV34_IzpdxcS8SU4L94Ak.jpg?quality=95&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=1080x0',
#                                                                'width': 1080},
#                                                               {'height': 1080,
#                                                                'type': 'z',
#                                                                'url': 'https://sun66-1.userapi.com/s/v1/ig2/LGKJCEWtZZlI4-hABbs6eiN_NuufX6UyCdco0z2MSQYfm9x3gnZZUnPbWrHO_-BFYSRSV34_IzpdxcS8SU4L94Ak.jpg?quality=95&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=1080x0',
#                                                                'width': 1080},
#                                                               {'height': 108,
#                                                                'type': 'o',
#                                                                'url': 'https://sun66-1.userapi.com/s/v1/ig2/LGKJCEWtZZlI4-hABbs6eiN_NuufX6UyCdco0z2MSQYfm9x3gnZZUnPbWrHO_-BFYSRSV34_IzpdxcS8SU4L94Ak.jpg?quality=95&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=108x0',
#                                                                'width': 108},
#                                                               {'height': 240,
#                                                                'type': 'p',
#                                                                'url': 'https://sun66-1.userapi.com/s/v1/ig2/LGKJCEWtZZlI4-hABbs6eiN_NuufX6UyCdco0z2MSQYfm9x3gnZZUnPbWrHO_-BFYSRSV34_IzpdxcS8SU4L94Ak.jpg?quality=95&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=240x0',
#                                                                'width': 240},
#                                                               {'height': 360,
#                                                                'type': 'q',
#                                                                'url': 'https://sun66-1.userapi.com/s/v1/ig2/LGKJCEWtZZlI4-hABbs6eiN_NuufX6UyCdco0z2MSQYfm9x3gnZZUnPbWrHO_-BFYSRSV34_IzpdxcS8SU4L94Ak.jpg?quality=95&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=360x0',
#                                                                'width': 360},
#                                                               {'height': 540,
#                                                                'type': 'r',
#                                                                'url': 'https://sun66-1.userapi.com/s/v1/ig2
},
#                                           'type': 'photo'}],
#                          'comments': {'count': 495},
#                          'date': 1721815992,
#                          'from_id': -22822305,
#                          'hash': 'aktoUngJ4q_PRfUAxA',
#                          'id': 1500176,
#                          'inner_type': 'wall_wallpost',
#                          'likes': {'can_like': 0,
#                                    'count': 1388,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_type': 'post',
#                          'push_subscription': {'is_subscribed': False},
#                          'reposts': {'count': 217},
#                          'text': 'Какие персонажи — такие и их любимые '
#                                  'плейлисты VK Музыки!\n'
#                                  '\n'
#                                  'А в комментарии можно скинуть свои любимые '
#                                  'плейлисты, если что 👇',
#                          'type': 'post',
#                          'views': {'count': 1157282}},
#                         {'attachments': [{'photo': {'access_key': 'f2cfb66e98ca1fd847',
#                                                     'album_id': -7,
#                                                     'date': 1721646311,
#                                                     'id': 457351557,
#                                                     'orig_photo': {'height': 1080,
#                                                                    'type': 'base',
#                                                                    'url': 'https://sun66-2.userapi.com/s/v1/ig2/aTnheFH4D3UzhwdjTTUhGpaX5vMZiVFaLKRT8wLcj7qHQvcpJbhV-bpSvuwBJrnjprc3lZ8fGZmas3rDC9BoeMZy.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu',
#                                                                    'width': 1080},
#                                                     'owner_id': -22822305,
#                                                     'post_id': 1499933,
#                                                     'sizes': [{'height': 72,
#                                                                'type': 's',
#                                                                'url': 'https://sun66-2.userapi.com/s/v1/ig2/aTnheFH4D3UzhwdjTTUhGpaX5vMZiVFaLKRT8wLcj7qHQvcpJbhV-bpSvuwBJrnjprc3lZ8fGZmas3rDC9BoeMZy.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=72x0',
#                                                                'width': 72},
#                                                               {'height': 160,
#                                                                'type': 'm',
#                                                                'url': 'https://sun66-2.userapi.com/s/v1/ig2/aTnheFH4D3UzhwdjTTUhGpaX5vMZiVFaLKRT8wLcj7qHQvcpJbhV-bpSvuwBJrnjprc3lZ8fGZmas3rDC9BoeMZy.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=160x0',
#                                                                'width': 160},
#                                                               {'height': 640,
#                                                                'type': 'x',
#                                                                'url': 'https://sun66-2.userapi.com/s/v1/ig2/aTnheFH4D3UzhwdjTTUhGpaX5vMZiVFaLKRT8wLcj7qHQvcpJbhV-bpSvuwBJrnjprc3lZ8fGZmas3rDC9BoeMZy.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=640x0',
#                                                                'width': 640},
#                                                               {'height': 1080,
#                                                                'type': 'y',
#                                                                'url': 'https://sun66-2.userapi.com/s/v1/ig2/aTnheFH4D3UzhwdjTTUhGpaX5vMZiVFaLKRT8wLcj7qHQvcpJbhV-bpSvuwBJrnjprc3lZ8fGZmas3rDC9BoeMZy.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=1080x0',
#                                                                'width': 1080},
#                                                               {'height': 1080,
#                                                                'type': 'z',
#                                                                'url': 'https://sun66-2.userapi.com/s/v1/ig2/aTnheFH4D3UzhwdjTTUhGpaX5vMZiVFaLKRT8wLcj7qHQvcpJbhV-bpSvuwBJrnjprc3lZ8fGZmas3rDC9BoeMZy.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=1080x0',
#                                                                'width': 1080},
#                                                               {'height': 108,
#                                                                'type': 'o',
#                                                                'url': 'https://sun66-2.userapi.com/s/v1/ig2/aTnheFH4D3UzhwdjTTUhGpaX5vMZiVFaLKRT8wLcj7qHQvcpJbhV-bpSvuwBJrnjprc3lZ8fGZmas3rDC9BoeMZy.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=108x0',
#                                                                'width': 108},
#                                                               {'height': 240,
#                                                                'type': 'p',
#                                                                'url': 'https://sun66-2.userapi.com/s/v1/ig2/aTnheFH4D3UzhwdjTTUhGpaX5vMZiVFaLKRT8wLcj7qHQvcpJbhV-bpSvuwBJrnjprc3lZ8fGZmas3rDC9BoeMZy.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=240x0',
#                                                                'width': 240},
#                                                               {'height': 360,
#                                                                'type': 'q',
#                                                                'url': 'https://sun66-2.userapi.com/s/v1/ig2/aTnheFH4D3UzhwdjTTUhGpaX5vMZiVFaLKRT8wLcj7qHQvcpJbhV-bpSvuwBJrnjprc3lZ8fGZmas3rDC9BoeMZy.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=360x0',
#                                                                'width': 360},
#                                                               {'height': 540,
#                                                                'type': 'r',
#                                                                'url': 'https://sun66-2.userapi.com/s/v1/ig2/aTnheFH4D3UzhwdjTTUhGpaX5vMZiVFaLKRT8wLcj7qHQvcpJbhV-bpSvuwBJrnjprc3lZ8fGZmas3rDC9BoeMZy.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu&cs=540x0',
#                                                                'width': 540},
#                                                               {'height': 1080,
#                                                                'type': 'base',
#                                                                'url': 'https://sun66-2.userapi.com/s/v1/ig2/aTnheFH4D3UzhwdjTTUhGpaX5vMZiVFaLKRT8wLcj7qHQvcpJbhV-bpSvuwBJrnjprc3lZ8fGZmas3rDC9BoeMZy.jpg?quality=96&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080&from=bu',
#                                                                'width': 1080}],
#                                                     'text': '',
#                                                     'user_id': 100,
#                                                     'web_view_token': 'f678de300e269fd417'},
#                                           'type': 'photo'}],
#                          'comments': {'count': 285},
#                          'date': 1721646311,
#                          'from_id': -22822305,
#                          'hash': 'MGoA5Pv5RhqtcGSrww',
#                          'id': 1499933,
#                          'inner_type': 'wall_wallpost',
#                          'likes': {'can_like': 0,
#                                    'count': 1341,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_type': 'post',
#                          'push_subscription': {'is_subscribed': False},
#                          'reposts': {'count': 135},
#                          'text': 'Негласное правило ВКонтакте №\u202f60',
#                          'type': 'post',
#                          'views': {'count': 468092}}]}}

# %%
len(response.json()['response']['items'])
# Out:
# 100

# %%
response.json()['response']['items'][0]
# Out:
# {'inner_type': 'wall_wallpost',
#  'comments': {'count': 97},
#  'marked_as_ads': 0,
#  'hash': 'KmfBJULnFiC85HSngg',
#  'type': 'post',
#  'push_subscription': {'is_subscribed': False},
#  'attachments': [{'type': 'photo',
#    'photo': {'album_id': -7,
#     'date': 1750674662,
#     'id': 457364376,
#     'owner_id': -22822305,
#     'access_key': 'b9d98a00ced8ca402b',
#     'sizes': [{'height': 72,
#       'type': 's',
#       'width': 72,
#       'url': 'https://sun66-1.userapi.com/s/v1/ig2/sV_3_Z5PFY6cWKrxN8A_KMEjD_40GRDokAuur3Yk5pqW5s4NOSJJ0xvowLFrOV54nSpY6uAdCfA4IA8KYwNQi4Pv.jpg?quality=95&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1500x1500&from=bu&cs=72x0'},
#      {'height': 160,
#       'type': 'm',
#       'width': 160,
#       'url': 'https://sun66-1.userapi.com/s/v1/ig2/sV_3_Z5PFY6cWKrxN8A_KMEjD_40GRDokAuur3Yk5pqW5s4NOSJJ0xvowLFrOV54nSpY6uAdCfA4IA8KYwNQi4Pv.jpg?quality=95&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1500x1500&from=bu&cs=160x0'},
#      {'height': 640,
#       'type': 'x',
#       'width': 640,
#       'url': 'https://sun66-1.userapi.com/s/v1/ig2/sV_3_Z5PFY6cWKrxN8A_KMEjD_40GRDokAuur3Yk5pqW5s4NOSJJ0xvowLFrOV54nSpY6uAdCfA4IA8KYwNQi4Pv.jpg?quality=95&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1500x1500&from=bu&cs=640x0'},
#      {'height': 1080,
#       'type': 'y',
#       'width': 1080,
#       'url': 'https://sun66-1.userapi.com/s/v1/ig2/sV_3_Z5PFY6cWKrxN8A_KMEjD_40GRDokAuur3Yk5pqW5s4NOSJJ0xvowLFrOV54nSpY6uAdCfA4IA8KYwNQi4Pv.jpg?quality=95&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1500x1500&from=bu&cs=1080x0'},
#      {'height': 1280,
#       'type': 'z',
#       'width': 1280,
#       'url': 'https://sun66-1.userapi.com/s/v1/ig2/sV_3_Z5PFY6cWKrxN8A_KMEjD_40GRDokAuur3Yk5pqW5s4NOSJJ0xvowLFrOV54nSpY6uAdCfA4IA8KYwNQi4Pv.jpg?quality=95&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1500x1500&from=bu&cs=1280x0'},
#      {'height': 1500,
#       'type': 'w',
#       'width': 1500,
#       'url': 'https://sun66-1.userapi.com/s/v1/ig2/sV_3_Z5PFY6cWKrxN8A_KMEjD_40GRDokAuur3Yk5pqW5s4NOSJJ0xvowLFrOV54nSpY6uAdCfA4IA8KYwNQi4Pv.jpg?quality=95&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1500x1500&from=bu&cs=1500x0'},
#      {'height': 108,
#       'type': 'o',
#       'width': 108,
#       'url': 'https://sun66-1.userapi.com/s/v1/ig2/sV_3_Z5PFY6cWKrxN8A_KMEjD_40GRDokAuur3Yk5pqW5s4NOSJJ0xvowLFrOV54nSpY6uAdCfA4IA8KYwNQi4Pv.jpg?quality=95&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1500x1500&from=bu&cs=108x0'},
#      {'height': 240,
#       'type': 'p',
#       'width': 240,
#       'url': 'https://sun66-1.userapi.com/s/v1/ig2/sV_3_Z5PFY6cWKrxN8A_KMEjD_40GRDokAuur3Yk5pqW5s4NOSJJ0xvowLFrOV54nSpY6uAdCfA4IA8KYwNQi4Pv.jpg?quality=95&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1500x1500&from=bu&cs=240x0'},
#      {'height': 360,
#       'type': 'q',
#       'width': 360,
#       'url': 'https://sun66-1.userapi.com/s/v1/ig2/sV_3_Z5PFY6cWKrxN8A_KMEjD_40GRDokAuur3Yk5pqW5s4NOSJJ0xvowLFrOV54nSpY6uAdCfA4IA8KYwNQi4Pv.jpg?quality=95&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1500x1500&from=bu&cs=360x0'},
#      {'height': 540,
#       'type': 'r',
#       'width': 540,
#       'url': 'https://sun66-1.userapi.com/s/v1/ig2/sV_3_Z5PFY6cWKrxN8A_KMEjD_40GRDokAuur3Yk5pqW5s4NOSJJ0xvowLFrOV54nSpY6uAdCfA4IA8KYwNQi4Pv.jpg?quality=95&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1500x1500&from=bu&cs=540x0'},
#      {'height': 1500,
#       'type': 'base',
#       'width': 1500,
#       'url': 'https://sun66-1.userapi.com/s/v1/ig2/sV_3_Z5PFY6cWKrxN8A_KMEjD_40GRDokAuur3Yk5pqW5s4NOSJJ0xvowLFrOV54nSpY6uAdCfA4IA8KYwNQi4Pv.jpg?quality=95&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1500x1500&from=bu'}],
#     'text': '',
#     'user_id': 100,
#     'web_view_token': 'fd753b313312247419',
#     'orig_photo': {'height': 1500,
#      'type': 'base',
#      'url': 'https://sun66-1.userapi.com/s/v1/ig2/sV_3_Z5PFY6cWKrxN8A_KMEjD_40GRDokAuur3Yk5pqW5s4NOSJJ0xvowLFrOV54nSpY6uAdCfA4IA8KYwNQi4Pv.jpg?quality=95&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1500x1500&from=bu',
#      'width': 1500}}}],
#  'date': 1750675407,
#  'from_id': -22822305,
#  'id': 1612255,
#  'likes': {'can_like': 0, 'count': 142, 'user_likes': 0},
#  'owner_id': -22822305,
#  'post_type': 'post',
#  'reposts': {'count': 16},
#  'text': '58 миллионов человек смотрят истории ВКонтакте каждый месяц\n\nЗа год просмотры историй выросли на 26%, а дневная аудитория — на 14%. Истории стали одним из самых быстрорастущих форматов на платформе.\n\nЕщё несколько интересных фактов из нашего исследования:\n• В среднем каждый зритель смотрит 23 истории в день\n• Активнее всего истории публикуют в выходные вечером\n• Почти миллион человек в день делятся историями только с друзьями',
#  'views': {'count': 42515}}

# %%
stats = {} 
count_post = 0 # Счётчик «непустых» сообщений
for record in response.json()['response']['items'][:]:
    title = record['text'][:30] 
    if title: 
        stats[title] = [record['comments']['count'], record['likes']['count'], record['reposts']['count'], record['date']] 
        count_post += 1 
    if count_post < 10: 
        continue 
    else: 
        break 
pprint(stats)
# Out:
# {'58 миллионов человек смотрят и': [97, 142, 16, 1750675407],
#  'POV: Оставили кота одного с но': [282, 272, 37, 1750427900],
#  'Вы приглашены в летний лагерь ': [158, 305, 25, 1750258247],
#  'Добрые стикеры ко Дню защиты д': [538, 911, 229, 1748610003],
#  'Не знаете, где взять те самые ': [203, 354, 37, 1750349841],
#  'Обновляем каналы ВКонтакте — у': [532, 791, 156, 1749563100],
#  'Онлайн-диалоги всё чаще начина': [434, 456, 94, 1750064757],
#  'Поздравляем с Днём России!\n\nДе': [371, 1582, 48, 1749719520],
#  'Редактор историй для сообществ': [272, 682, 186, 1749117242],
#  'Сегодня — День русского языка,': [218, 1079, 225, 1749200159]}
