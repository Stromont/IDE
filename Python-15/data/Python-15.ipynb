# %%
import os
def dirinfo(dir = os.getcwd()):
    for root, dirs, files in os.walk(dir):
        print("Текущая директория", root)
        print("---")

        if dirs:
            print("Список папок", dirs)
        else:
            print("Папок нет")
        print("---")

        if files:
            print("Список файлов", files)
        else:
            print("Файлов нет")
        print("---")

        if files and dirs:
            print("Все пути:")
        for f in files:
            print("Файл ", os.path.join(root, f))
        for d in dirs:
            print("Папка ", os.path.join(root, d))
        print("===")

# %%
crtpath="D:\TrafficMonitor\\"
dirinfo(crtpath)
# Out:
# Текущая директория D:\TrafficMonitor\
# ---
# Список папок ['Logo', 'skins']
# ---
# Список файлов ['config.ini', 'error.log', 'FAQ.url', 'global_cfg.ini', 'history_traffic.dat', 'history_traffic.dat.bak', 'Home.url', 'LibreHardwareMonitorLib.dll', 'OpenHardwareMonitorApi.dll', 'TrafficMonitor.exe', 'TrafficMonitor.VisualElementsManifest.xml']
# ---
# Все пути:
# Файл  D:\TrafficMonitor\config.ini
# Файл  D:\TrafficMonitor\error.log
# Файл  D:\TrafficMonitor\FAQ.url
# Файл  D:\TrafficMonitor\global_cfg.ini
# Файл  D:\TrafficMonitor\history_traffic.dat
# Файл  D:\TrafficMonitor\history_traffic.dat.bak
# Файл  D:\TrafficMonitor\Home.url
# Файл  D:\TrafficMonitor\LibreHardwareMonitorLib.dll
# Файл  D:\TrafficMonitor\OpenHardwareMonitorApi.dll
# Файл  D:\TrafficMonitor\TrafficMonitor.exe
# Файл  D:\TrafficMonitor\TrafficMonitor.VisualElementsManifest.xml
# Папка  D:\TrafficMonitor\Logo
# Папка  D:\TrafficMonitor\skins
# ===
# Текущая директория D:\TrafficMonitor\Logo
# ---
# Папок нет
# ---
# Список файлов ['TrafficMonitor.150x150Logo.png', 'TrafficMonitor.70x70Logo.png']
# ---
# Файл  D:\TrafficMonitor\Logo\TrafficMonitor.150x150Logo.png
# Файл  D:\TrafficMonitor\Logo\TrafficMonitor.70x70Logo.png
# ===
# Текущая директория D:\TrafficMonitor\skins
# ---
# Список папок ['0默认皮肤', '皮肤01', '皮肤02', '皮肤03', '皮肤04', '皮肤05', '皮肤06', '皮肤07', '皮肤08', '皮肤09', '皮肤10', '皮肤11', '皮肤12']
# ---
# Файлов нет
# ---
# Папка  D:\TrafficMonitor\skins\0默认皮肤
# Папка  D:\TrafficMonitor\skins\皮肤01
# Папка  D:\TrafficMonitor\skins\皮肤02
# Папка  D:\TrafficMonitor\skins\皮肤03
# Папка  D:\TrafficMonitor\skins\皮肤04
# Папка  D:\TrafficMonitor\skins\皮肤05
# Папка  D:\TrafficMonitor\skins\皮肤06
# Папка  D:\TrafficMonitor\skins\皮肤07
# Папка  D:\TrafficMonitor\skins\皮肤08
# Папка  D:\TrafficMonitor\skins\皮肤09
# Папка  D:\TrafficMonitor\skins\皮肤10
# Папка  D:\TrafficMonitor\skins\皮肤11
# Папка  D:\TrafficMonitor\skins\皮肤12
# ===
# Текущая директория D:\TrafficMonitor\skins\0默认皮肤
# ---
# Папок нет
# ---
# Список файлов ['background.bmp', 'background_l.bmp', 'background_mask.bmp', 'background_mask_l.bmp', 'skin.ini']
# ---
# Файл  D:\TrafficMonitor\skins\0默认皮肤\background.bmp
# Файл  D:\TrafficMonitor\skins\0默认皮肤\background_l.bmp
# Файл  D:\TrafficMonitor\skins\0默认皮肤\background_mask.bmp
# Файл  D:\TrafficMonitor\skins\0默认皮肤\background_mask_l.bmp
# Файл  D:\TrafficMonitor\skins\0默认皮肤\skin.ini
# ===
# Текущая директория D:\TrafficMonitor\skins\皮肤01
# ---
# Папок нет
# ---
# Список файлов ['background.bmp', 'background_l.bmp', 'background_mask.bmp', 'background_mask_l.bmp', 'skin.ini']
# ---
# Файл  D:\TrafficMonitor\skins\皮肤01\background.bmp
# Файл  D:\TrafficMonitor\skins\皮肤01\background_l.bmp
# Файл  D:\TrafficMonitor\skins\皮肤01\background_mask.bmp
# Файл  D:\TrafficMonitor\skins\皮肤01\background_mask_l.bmp
# Файл  D:\TrafficMonitor\skins\皮肤01\skin.ini
# ===
# Текущая директория D:\TrafficMonitor\skins\皮肤02
# ---
# Папок нет
# ---
# Список файлов ['background.bmp', 'background_l.bmp', 'background_mask.bmp', 'background_mask_l.bmp', 'skin.ini']
# ---
# Файл  D:\TrafficMonitor\skins\皮肤02\background.bmp
# Файл  D:\TrafficMonitor\skins\皮肤02\background_l.bmp
# Файл  D:\TrafficMonitor\skins\皮肤02\background_mask.bmp
# Файл  D:\TrafficMonitor\skins\皮肤02\background_mask_l.bmp
# Файл  D:\TrafficMonitor\skins\皮肤02\skin.ini
# ===
# Текущая директория D:\TrafficMonitor\skins\皮肤03
# ---
# Папок нет
# ---
# Список файлов ['background.bmp', 'background_l.bmp', 'skin.ini']
# ---
# Файл  D:\TrafficMonitor\skins\皮肤03\background.bmp
# Файл  D:\TrafficMonitor\skins\皮肤03\background_l.bmp
# Файл  D:\TrafficMonitor\skins\皮肤03\skin.ini
# ===
# Текущая директория D:\TrafficMonitor\skins\皮肤04
# ---
# Папок нет
# ---
# Список файлов ['background.bmp', 'background_l.bmp', 'skin.ini']
# ---
# Файл  D:\TrafficMonitor\skins\皮肤04\background.bmp
# Файл  D:\TrafficMonitor\skins\皮肤04\background_l.bmp
# Файл  D:\TrafficMonitor\skins\皮肤04\skin.ini
# ===
# Текущая директория D:\TrafficMonitor\skins\皮肤05
# ---
# Папок нет
# ---
# Список файлов ['background.bmp', 'background_l.bmp', 'skin.ini']
# ---
# Файл  D:\TrafficMonitor\skins\皮肤05\background.bmp
# Файл  D:\TrafficMonitor\skins\皮肤05\background_l.bmp
# Файл  D:\TrafficMonitor\skins\皮肤05\skin.ini
# ===
# Текущая директория D:\TrafficMonitor\skins\皮肤06
# ---
# Папок нет
# ---
# Список файлов ['background.bmp', 'background_l.bmp', 'skin.ini']
# ---
# Файл  D:\TrafficMonitor\skins\皮肤06\background.bmp
# Файл  D:\TrafficMonitor\skins\皮肤06\background_l.bmp
# Файл  D:\TrafficMonitor\skins\皮肤06\skin.ini
# ===
# Текущая директория D:\TrafficMonitor\skins\皮肤07
# ---
# Папок нет
# ---
# Список файлов ['background.bmp', 'background_l.bmp', 'skin.ini']
# ---
# Файл  D:\TrafficMonitor\skins\皮肤07\background.bmp
# Файл  D:\TrafficMonitor\skins\皮肤07\background_l.bmp
# Файл  D:\TrafficMonitor\skins\皮肤07\skin.ini
# ===
# Текущая директория D:\TrafficMonitor\skins\皮肤08
# ---
# Папок нет
# ---
# Список файлов ['background.bmp', 'background_l.bmp', 'skin.ini']
# ---
# Файл  D:\TrafficMonitor\skins\皮肤08\background.bmp
# Файл  D:\TrafficMonitor\skins\皮肤08\background_l.bmp
# Файл  D:\TrafficMonitor\skins\皮肤08\skin.ini
# ===
# Текущая директория D:\TrafficMonitor\skins\皮肤09
# ---
# Папок нет
# ---
# Список файлов ['background.bmp', 'background_l.bmp', 'skin.ini']
# ---
# Файл  D:\TrafficMonitor\skins\皮肤09\background.bmp
# Файл  D:\TrafficMonitor\skins\皮肤09\background_l.bmp
# Файл  D:\TrafficMonitor\skins\皮肤09\skin.ini
# ===
# Текущая директория D:\TrafficMonitor\skins\皮肤10
# ---
# Папок нет
# ---
# Список файлов ['background.bmp', 'background_l.bmp', 'skin.ini']
# ---
# Файл  D:\TrafficMonitor\skins\皮肤10\background.bmp
# Файл  D:\TrafficMonitor\skins\皮肤10\background_l.bmp
# Файл  D:\TrafficMonitor\skins\皮肤10\skin.ini
# ===
# Текущая директория D:\TrafficMonitor\skins\皮肤11
# ---
# Папок нет
# ---
# Список файлов ['background.bmp', 'background_l.bmp', 'skin.ini']
# ---
# Файл  D:\TrafficMonitor\skins\皮肤11\background.bmp
# Файл  D:\TrafficMonitor\skins\皮肤11\background_l.bmp
# Файл  D:\TrafficMonitor\skins\皮肤11\skin.ini
# ===
# Текущая директория D:\TrafficMonitor\skins\皮肤12
# ---
# Папок нет
# ---
# Список файлов ['background.bmp', 'background_l.bmp', 'skin.xml']
# ---
# Файл  D:\TrafficMonitor\skins\皮肤12\background.bmp
# Файл  D:\TrafficMonitor\skins\皮肤12\background_l.bmp
# Файл  D:\TrafficMonitor\skins\皮肤12\skin.xml
# ===
# <>:1: SyntaxWarning: invalid escape sequence '\T'
# <>:1: SyntaxWarning: invalid escape sequence '\T'
# C:\Users\Stromont\AppData\Local\Temp\ipykernel_8196\306071671.py:1: SyntaxWarning: invalid escape sequence '\T'
#   crtpath="D:\TrafficMonitor\\"
